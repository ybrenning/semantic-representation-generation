# %% [markdown]
# # Final formatting notebook
#
# This notebook contains all the code to go from the initially generated datasets (naturalistic sentences and controlled ones) to build the final files:
# - In one folder: stim/audio, we have all the audio files, with a naming convention for each dataset:
#     - Naturalistic: sentence_id.wav
#     - Controlled: tense_theme_plurality_variation.wav
# - In another folder: stim/sentences/clean, we have:
#     - a csv file with all the sentences: final.csv, and two columns: one called audio_filename, to link it to the audio file, and another one called block_number_subX which links it to the block it belongs for a given subject.
#     - the naturalistic.csv file which contains the inital 32K sentences.
#     - the controlled sentences dataset in the controlled.csv file.
#     - a notebook that was used to generate all the given files, to track how it was done and reproduce it if needed.

# %% [markdown]
# # Natural dataset

# %% [markdown]
# ## Extract N-words vocab, tag them if incorrect and fix them, while filtering for negative sentences
#
# I need 10 subjects x 2000 sentences: 20 000 sentences

# %% [markdown]
# Remove most negative sentences

# %%
from pathlib import Path
import pandas as pd

naturalistic_path = Path('./../stim/text/full.csv')
naturalistic_df = pd.read_csv(naturalistic_path)

# Remove the \n from the sentence text field
naturalistic_df['sentence'] = naturalistic_df['sentence'].str.replace('\n', '')

# Adjust ratio of negative sentences
negative_sentences = naturalistic_df[naturalistic_df['polarity'] == 'negative']
non_negative_sentences = naturalistic_df[naturalistic_df['polarity'] != 'negative']

# Calculate how many negative sentences to keep (10% of total)
total_desired = len(non_negative_sentences) // 4  # This will make negatives 10% of final
negative_to_keep = min(len(negative_sentences), total_desired)


# Randomly sample negative sentences
kept_negative = negative_sentences.sample(n=negative_to_keep)

# Combine with non-negative sentences
polarity_balanced_df = pd.concat([non_negative_sentences, kept_negative])

# %% [markdown]
# Filter the vocab so we have around 30K sentences

# %%
# Filter naturalistic dataset
# Get the 3000 most common words
words_count = {}
for sentence in polarity_balanced_df['sentence']:
    words = str(sentence).split()
    for word in words:
        words_count[word] = words_count.get(word, 0) + 1

most_common_words = sorted(words_count, key=words_count.get, reverse=True)[:12000]

# Filter sentences with common words and length limit
filtered_sentences = []
for sentence in polarity_balanced_df['sentence'][polarity_balanced_df['num_words'] <= 12]:
    words = set(str(sentence).split())
    if all(word in most_common_words for word in words):
        filtered_sentences.append(sentence)

# Create final filtered dataframe
final_df = polarity_balanced_df[polarity_balanced_df['sentence'].isin(filtered_sentences)]

# %%
final_df.polarity.value_counts()
# Out:
# polarity
# affirmative    19072
# negative        4232
# Name: count, dtype: int64

# %%
final_df_tagged.validity_huge_issue.value_counts()

valid_share = final_df_tagged.validity_huge_issue.value_counts()[0] / len(final_df_tagged)
valid_share
# Out:
# /tmp/ipykernel_96151/1585341391.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   valid_share = final_df_tagged.validity_huge_issue.value_counts()[0] / len(final_df_tagged)
# 0.8471507037418469

# %%
final_df.num_words.value_counts()
# Out:
# num_words
# 10    5558
# 9     5338
# 11    3610
# 8     3472
# 7     2316
# 6     1270
# 12    1170
# 5      443
# 4      123
# 3        4
# Name: count, dtype: int64

# %% [markdown]
# Check the validity of all the sentences

# %% [markdown]
# #### Functions

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from tqdm import tqdm

def process_dataframe_parallel(df, max_workers=50, check=""):
    # Create a copy of the dataframe with a temporary sequential index
    temp_df = df.reset_index(drop=False)
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        if check == "huge_issue":
            # Include both index and sentence in the future
            futures = {
                executor.submit(
                    check_sentence_huge_issue, 
                    row['sentence'],
                    temp_idx
                ): temp_idx 
                for temp_idx, row in temp_df.iterrows()
            }
        else:
            raise ValueError("Invalid check")
            
        results = []
        for future in tqdm(futures, total=len(futures), desc="Processing sentences"):
            try:
                result = future.result()
                temp_idx = futures[future]
                results.append((temp_idx, result))
            except Exception as e:
                temp_idx = futures[future]
                results.append((temp_idx, 'unsure'))
    
    # Sort by the temporary index
    results.sort(key=lambda x: x[0])
    
    # Create the new column
    temp_df[f'validity_{check}'] = [r[1] for r in results]
    
    # Restore the original index and return
    return temp_df.set_index(df.index)

def check_sentence_huge_issue(sentence, idx):
    prompt = f"""Is this sentence correct? 
Reply with either one word: 'correct' if the sentence is perfectly fine, otherwise, if there's any issue, output 'incorrect'.
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        return response
    except Exception as e:
        print(f"Error at index {idx}: {e}")
        return 'bugged'
    

OPENAI_API_KEY = "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"
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)


def gpt4_response(prompt, model="gpt-4o-mini"):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model=model,
    )

    return chat_completion.choices[0].message.content

# %% [markdown]
# #### Check validty

# %%
final_df
# Out:
#               theme           type    structure     numer    tense  \
# 60          weather  interrogative       simple    plural  present
# 61          weather  interrogative       simple    plural  present
# 62          weather  interrogative       simple    plural  present
# 63          weather  interrogative       simple    plural  present
# 64          weather  interrogative       simple    plural  present
# ...             ...            ...          ...       ...      ...
# 24949     transport     imperative  preposition    plural   future
# 23194         sport     imperative  independent  singular     past
# 35435         sport     imperative       simple  singular   future
# 18124         sport    declarative  preposition    plural   future
# 17302  relationship     imperative    dependent    plural   future
#
#           polarity                                           sentence  \
# 60     affirmative  Are the temperatures rising during the summer ...
# 61     affirmative    Do the clouds usually appear thicker in spring?
# 62     affirmative   Are winter storms becoming more frequent lately?
# 63     affirmative     Have the winds picked up speed this afternoon?
# 64     affirmative      Is it true that flowers only bloom in spring?
# ...            ...                                                ...
# 24949     negative    Will you not drive through the tunnel at night?
# 23194     negative  The runner has not stopped because he hadn’t r...
# 35435     negative  Don't ignore the rules outlined before the eve...
# 18124     negative  The athletes will not run among the trees duri...
# 17302     negative  Ensure your parents won't allow those you disl...
#
#        num_words
# 60             8
# 61             8
# 62             7
# 63             8
# 64             9
# ...          ...
# 24949          9
# 23194         11
# 35435          9
# 18124         10
# 17302         10
#
# [23245 rows x 8 columns]

# %% [markdown]
# #### Final run on all

# %%
final_df_tagged = process_dataframe_parallel(final_df, max_workers=50, check="huge_issue")
# Out:
# Processing sentences: 100%|██████████| 23304/23304 [06:33<00:00, 59.18it/s]

# %% [markdown]
# ### Add the index in the file

# %%
import pandas as pd
from pathlib import Path

base_path = Path("/home/co/git/neurospin-new-protocol/")
naturalistic_df = pd.read_csv(base_path / "stim/sentences/V2/processed/natural_two_passes_fixed.csv")

df = naturalistic_df

# %%
# Add a column which refers to the sentence id, basically the index encoded as XXXXX, and another column as the audio file name
df['sentence_id'] = df.index.map(lambda x: f"nat_{x:05d}")
df['audio_filename'] = df['sentence_id'].apply(lambda x: f"{x}.wav")

df.to_csv(base_path / "stim/sentences/V2/processed/natural_two_passes_fixed.csv", index=False)

# %% [markdown]
# # Controlled dataset

# %% [markdown]
# ## Reformatting it correctly

# %%
controlled_raw_path = Path("/home/co/git/neurospin-new-protocol/stim/sentences/V2/processed/controlled_revised.csv")
controlled_raw_df = pd.read_csv(controlled_raw_path)
# Remove the nan values
controlled_raw_df = controlled_raw_df.dropna(subset=['sentence'])

# Remvoe some useless conditions for our experiment
controlled_raw_df.structure.unique()

# Check how many sentences we have if we filter out: the nested_* structures
filtered_controlled_df = controlled_raw_df[~controlled_raw_df.structure.str.contains("nested_object")]

# Add now a column that gives this info:df['sentence_id'] = df.index.map(lambda x: f"nat_{x:05d}")
# df['audio_filename'] = df['sentence_id'].apply(lambda x: f"{x}.wav")

filtered_controlled_df['sentence_id'] = filtered_controlled_df.index.map(lambda x: f"ctr_{x:05d}")
filtered_controlled_df['audio_filename'] = filtered_controlled_df['sentence_id'].apply(lambda x: f"{x}.wav")

filtered_controlled_df
# Save it to a csv file

filtered_controlled_df.to_csv(Path("/home/co/git/neurospin-new-protocol/stim/sentences/V2/processed/controlled_filtered.csv"), index=False)
# Out:
# /tmp/ipykernel_493701/1254500208.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_controlled_df['sentence_id'] = filtered_controlled_df.index.map(lambda x: f"ctr_{x:05d}")
# /tmp/ipykernel_493701/1254500208.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_controlled_df['audio_filename'] = filtered_controlled_df['sentence_id'].apply(lambda x: f"{x}.wav")

# %% [markdown]
# ## Running the synonym replacement

# %% [markdown]
# ### V5 - Using Jérémy's idea and a bit more chill (previous versions can be found in previous commits)

# %%
import pandas as pd
import json
import random
import os
from pathlib import Path
from openai import Client
from concurrent.futures import ThreadPoolExecutor
from functools import partial
import time
import backoff

OPENAI_API_KEY = "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"

MAX_RETRIES = 1
MAX_WORKERS = 50  # Adjust based on your API rate limits

client = Client(api_key=OPENAI_API_KEY)

@backoff.on_exception(backoff.expo, Exception, max_tries=MAX_RETRIES)
def gpt4_response_base(prompt, model):
    try:
        chat_completion = client.chat.completions.create(
            messages=[{"role": "user", "content": prompt}],
            model=model,
            timeout=30  # Add timeout to prevent hanging
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        print(f"Error in API call: {str(e)}")
        raise

def create_synonym_prompt(sentence):
    return f"""Analyze this sentence and provide single-word synonyms (0-3) WHEN POSSIBLE for content words (nouns, verbs, adjectives, adverbs).
Rules:
- Each synonym must be exactly ONE word
- Only provide synonyms that:
  * Have the EXACT same meaning in the given sentence context
  * Keep the same:
    - part of speech
    - grammatical form
    - tense (for verbs) 
    - and numerosity (singular/plural): never replace product with goods
  * Could replace the original word without changing meaning or naturalness
- Provide NO synonyms if:
  * There isn't a perfect meaning match
  * The replacement would sound unnatural
- Make sure that all the synonyms combination could work with each other. Stay simple.

Sentence: "{sentence}"

Return as JSON:
{{"original_word": ["synonym1", "synonym2"]}}

Example 1:
Input: "The experienced doctors treated patients carefully"
{{"experienced": ["skilled"], "doctors": ["physicians"], "treated": ["handled"], "carefully": ["cautiously"]}}

Example 2:
Input: "Teachers warmly greet students"
{{"teachers": ["professors"], "warmly": ["kindly"], "greet": ["welcome"], "students": ["pupils"]}}"""


def create_sentence_variation(sentence, synonyms_dict):
    words = sentence.split()
    new_words = []
    modified = False
    print(f"\nProcessing sentence: {sentence}")

    for word in words:
        print(f"Processing word: {word}")
        print(f"Synonyms dict: {synonyms_dict}")
        # Strip punctuation for lookup but keep track of it
        punct = ''
        if not word.isalnum():
            punct = word[-1] if not word[-1].isalnum() else ''
            word = word[:-1] if punct else word
        
        word_lower = word.lower()
        
        if word_lower in synonyms_dict and synonyms_dict[word_lower]:
            all_options = [word] + synonyms_dict[word_lower]
            replacement = random.choice(all_options)
            if word[0].isupper():
                replacement = replacement.capitalize()
            # Add back punctuation
            new_words.append(replacement + punct)
            if replacement != word:
                modified = True
            print(f"Replaced '{word}' with '{replacement}'")
        else:
            new_words.append(word + punct)
            print(f"Kept '{word}'")

    return " ".join(new_words), modified

def parse_llm_response(response):
    try:
        cleaned_response = response.strip()
        if cleaned_response.startswith('```'):
            cleaned_response = cleaned_response.split('```')[1]
        if cleaned_response.startswith('json'):
            cleaned_response = cleaned_response[4:]
        return json.loads(cleaned_response.strip())
    except json.JSONDecodeError:
        print(f"Error parsing response: {response}")
        return {}

def get_cache_key(sentence):
    # Using both hash and index/id if available
    return f"{hash(sentence)}"

def get_synonyms_for_sentence(sentence, cache_dir="synonym_cache"):
    Path(cache_dir).mkdir(exist_ok=True)
    cache_key = get_cache_key(sentence)
    cache_file = Path(cache_dir) / f"{cache_key}.json"

    if cache_file.exists():
        try:
            with open(cache_file, 'r') as f:
                return json.load(f)
        except (json.JSONDecodeError, FileNotFoundError):
            pass

    prompt = create_synonym_prompt(sentence)
    response = gpt4_response_base(prompt, "gpt-4o")
    synonyms_dict = parse_llm_response(response)

    with open(cache_file, 'w') as f:
        json.dump(synonyms_dict, f)

    return synonyms_dict

def process_sentence(sentence, idx):
    try:
        synonyms = get_synonyms_for_sentence(sentence)
        new_sentence, was_modified = create_sentence_variation(sentence, synonyms)
        return idx, new_sentence, was_modified
    except Exception as e:
        print(f"Error processing sentence {idx}: {str(e)}")
        return idx, sentence, False



def generate_variations(df, batch_size=10):
    new_df = df.copy()
    new_df['original_sentence'] = new_df['sentence']
    
    # Process sentences in batches using ThreadPoolExecutor
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        for i in range(0, len(df), batch_size):
            batch = df.iloc[i:i+batch_size]
            futures = []
            
            for idx, row in batch.iterrows():
                future = executor.submit(process_sentence, row['sentence'], idx)
                futures.append(future)
            
            # Process completed futures
            for future in futures:
                try:
                    idx, new_sentence, was_modified = future.result()
                    if was_modified:
                        new_df.at[idx, 'sentence'] = new_sentence
                except Exception as e:
                    print(f"Error processing future: {str(e)}")
                    continue
            
            # Add a small delay between batches to avoid rate limits
            time.sleep(0.1)
    
    return new_df

# %%
# Example usage
testing_df = controlled_df.loc[:50].copy()
new_df = generate_variations(testing_df, batch_size=50)
# Out:
# Processing sentence: The artists in their studios painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'in'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'studios' with 'workshops'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'painted' with 'colored'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists who the critics admired painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'critics' with 'reviewers'
# Processing word: admired
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'admired' with 'admired'
# Processing word: painted
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'yesterday' with 'recently'
#
# Processing sentence: The painter awkwardly created the sculpture.
# Processing word: The
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Kept 'The'
# Processing word: painter
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Replaced 'painter' with 'painter'
# Processing word: awkwardly
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Kept 'awkwardly'
# Processing word: created
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Replaced 'created' with 'created'
# Processing word: the
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Kept 'the'
# Processing word: sculpture.
# Synonyms dict: {'painter': ['artist'], 'created': ['made']}
# Kept 'sculpture'
#
# Processing sentence: The painter created the sculpture.
# Processing word: The
# Synonyms dict: {'painter': ['artist'], 'created': ['crafted']}
# Kept 'The'
# Processing word: painter
# Synonyms dict: {'painter': ['artist'], 'created': ['crafted']}
# Replaced 'painter' with 'artist'
# Processing word: created
# Synonyms dict: {'painter': ['artist'], 'created': ['crafted']}
# Replaced 'created' with 'created'
# Processing word: the
# Synonyms dict: {'painter': ['artist'], 'created': ['crafted']}
# Kept 'the'
# Processing word: sculpture.
# Synonyms dict: {'painter': ['artist'], 'created': ['crafted']}
# Kept 'sculpture'
#
# Processing sentence: The artists who the instructors who the school pays teach paint new pictures.
# Processing word: The
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'artists'
# Processing word: who
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: instructors
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'instructors'
# Processing word: who
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: school
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'school'
# Processing word: pays
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'pays'
# Processing word: teach
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'teach'
# Processing word: paint
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'paint': ['draw'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The artists painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Replaced 'artists' with 'artists'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'yesterday'
#
# Processing sentence: The artists in the studios paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'studios' with 'studios'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'pictures' with 'artworks'
#
# Processing sentence: The talented artists who read the books that are on the shelves quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'who'
# Processing word: read
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'read'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'the'
# Processing word: books
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'books'
# Processing word: that
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'that'
# Processing word: are
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'are'
# Processing word: on
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'on'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'the'
# Processing word: shelves
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'shelves'
# Processing word: quickly
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['illustrations']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'artists' with 'painters'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'painted' with 'created'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'yesterday'
#
# Processing sentence: The artists who practice every day paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'who'
# Processing word: practice
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'practice' with 'train'
# Processing word: every
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'every'
# Processing word: day
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'day'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'pictures' with 'artworks'
#
# Processing sentence: The artists who the gallery owners hire paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: gallery
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'gallery'
# Processing word: owners
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'owners'
# Processing word: hire
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'hire'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'paintings'
#
# Processing sentence: The artists who the gallery owners hire quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: gallery
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'gallery'
# Processing word: owners
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'owners'
# Processing word: hire
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'hire'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'paintings'
#
# Processing sentence: The talented artists who practice every day paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'who'
# Processing word: practice
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'practice' with 'train'
# Processing word: every
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'every'
# Processing word: day
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'day'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'artists' with 'artists'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'painters'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The artists quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'quickly' with 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The artists in the studios quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'studios' with 'studios'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists who practice every day quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: practice
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'practice' with 'practice'
# Processing word: every
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'every'
# Processing word: day
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'day'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'practice': ['train'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'paintings'
#
# Processing sentence: The artists who the critics admired painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'critics'
# Processing word: admired
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'admired' with 'admired'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The artists who the instructors who the school pays teach quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: instructors
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Replaced 'instructors' with 'instructors'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: school
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'school'
# Processing word: pays
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'pays'
# Processing word: teach
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'teach'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'instructors': ['teachers'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists who trained hard attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'trained'
# Processing word: hard
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'hard'
# Processing word: attentively
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'painted' with 'crafted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists who read the books that were on the shelves attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'who'
# Processing word: read
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'read'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'the'
# Processing word: books
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'books'
# Processing word: that
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'that'
# Processing word: were
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'were'
# Processing word: on
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'on'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'the'
# Processing word: shelves
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'shelves'
# Processing word: attentively
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'attentively'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'painted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'canvases': ['panels']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists who the gallery owners hire paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: gallery
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'gallery'
# Processing word: owners
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'owners'
# Processing word: hire
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'hire'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists in the studios paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'studios' with 'studios'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The talented artists quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: quickly
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'quickly' with 'quickly'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The artists who trained hard painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'trained' with 'trained'
# Processing word: hard
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'hard'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'yesterday'
#
# Processing sentence: The artists who the curators who the museums respected supported painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'the'
# Processing word: curators
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'curators'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'the'
# Processing word: museums
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'museums' with 'museums'
# Processing word: respected
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'respected'
# Processing word: supported
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'supported'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'museums': ['galleries'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'yesterday' with 'previously'
#
# Processing sentence: The talented artists who read the books that are on the shelves paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'who'
# Processing word: read
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'read'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: books
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'books'
# Processing word: that
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'that'
# Processing word: are
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'are'
# Processing word: on
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'on'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: shelves
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'shelves'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Replaced 'paint' with 'draw'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create', 'draw'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists who read the books that were on the shelves painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'who'
# Processing word: read
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'read'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'the'
# Processing word: books
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'books'
# Processing word: that
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'that'
# Processing word: were
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'were'
# Processing word: on
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'on'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'the'
# Processing word: shelves
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'shelves' with 'racks'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'canvases' with 'portraits'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# ...
# Kept 'the'
# Processing word: school
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'school' with 'academy'
# Processing word: pays
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'pays'
# Processing word: teach
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'teach'
# Processing word: paint
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'school': ['academy'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists who trained hard painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'trained' with 'practiced'
# Processing word: hard
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'hard' with 'diligently'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'canvases' with 'surfaces'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'yesterday' with 'previously'
#
# Processing sentence: The talented artists who the instructors who the school pays teach quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: instructors
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'instructors' with 'teachers'
# Processing word: who
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'the'
# Processing word: school
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'school'
# Processing word: pays
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'pays'
# Processing word: teach
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'teach' with 'instruct'
# Processing word: quickly
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'quickly' with 'quickly'
# Processing word: paint
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'instructors': ['teachers'], 'teach': ['instruct'], 'quickly': ['rapidly'], 'paint': ['draw'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The artists who the curators who the museums respected supported attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'the'
# Processing word: curators
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'curators' with 'curators'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'the'
# Processing word: museums
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'museums' with 'museums'
# Processing word: respected
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'respected' with 'esteemed'
# Processing word: supported
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'supported' with 'supported'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'painted' with 'colored'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'curators': ['custodians'], 'museums': ['galleries'], 'respected': ['esteemed'], 'supported': ['aided'], 'attentively': ['carefully'], 'painted': ['colored'], 'canvases': ['paintings'], 'yesterday': ['previously']}
# Replaced 'yesterday' with 'yesterday'
#
# Processing sentence: The artists who the critics admired attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'critics' with 'reviewers'
# Processing word: admired
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'admired' with 'praised'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'yesterday' with 'yesterday'
#
# Processing sentence: The talented painter created the sculpture.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Replaced 'talented' with 'skilled'
# Processing word: painter
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Replaced 'painter' with 'artist'
# Processing word: created
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Replaced 'created' with 'created'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Kept 'the'
# Processing word: sculpture.
# Synonyms dict: {'talented': ['skilled'], 'painter': ['artist'], 'created': ['crafted']}
# Kept 'sculpture'

# %%
new_df[['original_sentence', 'sentence']].head(50)
# Out:
#                                     original_sentence  \
# 0       The artists painted their canvases yesterday.
# 1   The artists attentively painted their canvases...
# 2   The talented artists painted their canvases ye...
# 3   The talented artists attentively painted their...
# 4   The artists in their studios painted their can...
# 5   The artists in their studios attentively paint...
# 6   The talented artists in their studios painted ...
# 7   The talented artists in their studios attentiv...
# 8   The artists who trained hard painted their can...
# 9   The artists who trained hard attentively paint...
# 10  The talented artists who trained hard painted ...
# 11  The talented artists who trained hard attentiv...
# 12  The artists who the critics admired painted th...
# 13  The artists who the critics admired attentivel...
# 14  The talented artists who the critics admired p...
# 15  The talented artists who the critics admired a...
# 16  The artists who read the books that were on th...
# 17  The artists who read the books that were on th...
# 18  The talented artists who read the books that w...
# 19  The talented artists who read the books that w...
# 20  The artists who the curators who the museums r...
# 21  The artists who the curators who the museums r...
# 22  The talented artists who the curators who the ...
# 23  The talented artists who the curators who the ...
# 24                    The artists paint new pictures.
# 25            The artists quickly paint new pictures.
# 26           The talented artists paint new pictures.
# 27   The talented artists quickly paint new pictures.
# 28     The artists in the studios paint new pictures.
# 29  The artists in the studios quickly paint new p...
# 30  The talented artists in the studios paint new ...
# 31  The talented artists in the studios quickly pa...
# 32  The artists who practice every day paint new p...
# 33  The artists who practice every day quickly pai...
# 34  The talented artists who practice every day pa...
# 35  The talented artists who practice every day qu...
# 36  The artists who the gallery owners hire paint ...
# 37  The artists who the gallery owners hire quickl...
# 38  The talented artists who the gallery owners hi...
# 39  The talented artists who the gallery owners hi...
# 40  The artists who read the books that are on the...
# 41  The artists who read the books that are on the...
# 42  The talented artists who read the books that a...
# 43  The talented artists who read the books that a...
# 44  The artists who the instructors who the school...
# 45  The artists who the instructors who the school...
# 46  The talented artists who the instructors who t...
# 47  The talented artists who the instructors who t...
# 48                 The painter created the sculpture.
# 49       The painter awkwardly created the sculpture.
#
#                                              sentence
# 0       The artists painted their canvases yesterday.
# 1   The artists attentively decorated their canvas...
# 2   The talented painters created their canvases y...
# 3   The talented painters carefully crafted their ...
# 4   The artists in their workshops colored their p...
# 5   The artists in their studios attentively paint...
# 6   The talented creators in their studios decorat...
# 7   The skilled artists in their studios attentive...
# 8   The artists who trained hard decorated their c...
# 9   The painters who trained diligently attentivel...
# 10  The talented artists who practiced diligently ...
# 11  The skilled artists who trained hard carefully...
# 12  The painters who the critics admired painted t...
# 13  The artists who the reviewers praised carefull...
# 14  The talented painters who the reviewers admire...
# 15  The talented artists who the critics admired c...
# 16  The painters who read the books that were on t...
# 17  The painters who perused the books that were o...
# 18  The talented painters who read the books that ...
# 19  The talented painters who read the books that ...
# 20  The artists who the curators who the museums r...
# 21  The artists who the curators who the museums e...
# 22  The gifted artists who the curators who the mu...
# 23  The talented artists who the curators who the ...
# 24                   The artists create new pictures.
# 25              The artists quickly paint new images.
# 26           The talented painters create new images.
# 27    The talented artists quickly create new images.
# 28     The artists in the studios paint new artworks.
# 29  The artists in the studios quickly paint new p...
# 30  The talented artists in the studios create new...
# 31  The skilled creators in the workshops quickly ...
# 32  The artists who train every day paint new artw...
# 33  The painters who practice every day quickly cr...
# 34  The talented painters who train every day crea...
# 35  The talented artists who practice every day ra...
# 36  The painters who the gallery owners hire paint...
# 37  The painters who the gallery owners hire quick...
# 38  The talented painters who the gallery owners h...
# 39  The skilled artists who the gallery proprietor...
# 40  The artists who read the books that are on the...
# 41  The painters who read the volumes that are on ...
# 42  The talented artists who read the books that a...
# 43  The skilled artists who read the books that ar...
# 44  The artists who the instructors who the school...
# 45  The painters who the instructors who the schoo...
# 46  The talented painters who the teachers who the...
# 47  The talented artists who the teachers who the ...
# 48                  The artist created the sculpture.
# 49       The painter awkwardly created the sculpture.

# %% [markdown]
# ### Full run before re-organizing

# %%
# Generate variations
augmented_df = generate_variations(filtered_controlled_df, batch_size=50)
# Out:
# Processing sentence: The artists attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'artists' with 'painters'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['decorated'], 'canvases': ['surfaces']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'artists' with 'painters'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['created']}
# Kept 'yesterday'
#
# Processing sentence: The artists painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Replaced 'artists' with 'painters'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Replaced 'painted' with 'created'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'painted': ['created']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Replaced 'talented' with 'gifted'
# Processing word: artists
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Replaced 'artists' with 'artists'
# Processing word: attentively
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Replaced 'painted' with 'crafted'
# Processing word: their
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Replaced 'canvases' with 'surfaces'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['surfaces']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists in their studios attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Replaced 'artists' with 'painters'
# Processing word: in
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'in'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'their'
# Processing word: studios
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'studios'
# Processing word: attentively
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Replaced 'painted' with 'crafted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['artworks']}
# Kept 'yesterday'
#
# Processing sentence: The artists who trained hard painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'trained' with 'practiced'
# Processing word: hard
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'hard'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Replaced 'canvases' with 'panels'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'painted': ['decorated'], 'canvases': ['panels']}
# Kept 'yesterday'
#
# Processing sentence: The artists in their studios attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Kept 'in'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Kept 'their'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Replaced 'studios' with 'workshops'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['panels']}
# Kept 'yesterday'
#
# Processing sentence: The artists in their studios painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'in'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'studios' with 'studios'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'painted' with 'depicted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'painted': ['colored', 'depicted'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists in their studios painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Kept 'in'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: studios
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Replaced 'studios' with 'studios'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'painted': ['decorated'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists who the critics admired painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'critics' with 'reviewers'
# Processing word: admired
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'admired' with 'admired'
# Processing word: painted
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'painted' with 'created'
# Processing word: their
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'yesterday' with 'yesterday'
#
# Processing sentence: The artists who the critics admired attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'critics' with 'critics'
# Processing word: admired
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'admired' with 'admired'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'critics': ['reviewers'], 'admired': ['praised'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings'], 'yesterday': ['recently']}
# Replaced 'yesterday' with 'recently'
#
# Processing sentence: The talented artists who trained hard attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'trained'
# Processing word: hard
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'hard'
# Processing word: attentively
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'attentively' with 'attentively'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'painted' with 'crafted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The artists who the critics admired painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'critics'
# Processing word: admired
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'admired' with 'praised'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'painted' with 'created'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'admired': ['praised'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The artists who trained hard attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'trained' with 'practiced'
# Processing word: hard
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'hard' with 'diligently'
# Processing word: attentively
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'painted' with 'created'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'attentively': ['carefully'], 'painted': ['created'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The talented artists who trained hard painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'trained' with 'trained'
# Processing word: hard
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'hard' with 'hard'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'canvases' with 'surfaces'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'trained': ['practiced'], 'hard': ['diligently'], 'painted': ['decorated'], 'canvases': ['surfaces'], 'yesterday': ['previously']}
# Replaced 'yesterday' with 'previously'
#
# Processing sentence: The artists who read the books that were on the shelves painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'who'
# Processing word: read
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'read'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'the'
# Processing word: books
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'books'
# Processing word: that
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'that'
# Processing word: were
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'were'
# Processing word: on
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'on'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'the'
# Processing word: shelves
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'shelves' with 'shelves'
# Processing word: painted
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'painted' with 'decorated'
# Processing word: their
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'canvases' with 'canvases'
# Processing word: yesterday.
# Synonyms dict: {'artists': ['painters'], 'shelves': ['racks'], 'painted': ['decorated'], 'canvases': ['portraits'], 'yesterday': ['earlier']}
# Replaced 'yesterday' with 'earlier'
#
# Processing sentence: The artists quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'quickly' with 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The talented artists who the critics admired attentively painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'the'
# Processing word: critics
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'critics'
# Processing word: admired
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'admired' with 'respected'
# Processing word: attentively
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'attentively' with 'carefully'
# Processing word: painted
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'painted' with 'painted'
# Processing word: their
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'their'
# Processing word: canvases
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Replaced 'canvases' with 'paintings'
# Processing word: yesterday.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'admired': ['respected'], 'attentively': ['carefully'], 'painted': ['crafted'], 'canvases': ['paintings']}
# Kept 'yesterday'
#
# Processing sentence: The artists in the studios paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'studios' with 'studios'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['artworks']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'artists' with 'painters'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'paint': ['create'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'paintings'
#
# Processing sentence: The talented artists in the studios paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'artists'
# Processing word: in
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'studios' with 'studios'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists in the studios quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'skilled'
# Processing word: artists
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'creators'
# Processing word: in
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'studios' with 'workshops'
# Processing word: quickly
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'quickly' with 'quickly'
# Processing word: paint
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['skilled'], 'artists': ['creators'], 'studios': ['workshops'], 'quickly': ['swiftly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'images'
#
# Processing sentence: The talented artists who practice every day quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'talented' with 'talented'
# Processing word: artists
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'painters'
# Processing word: who
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'who'
# Processing word: practice
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'practice' with 'practice'
# Processing word: every
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'every'
# Processing word: day
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'day'
# Processing word: quickly
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'quickly' with 'rapidly'
# Processing word: paint
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'paint'
# Processing word: new
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'talented': ['gifted'], 'artists': ['painters'], 'practice': ['train'], 'quickly': ['rapidly'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists in the studios quickly paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'artists' with 'painters'
# Processing word: in
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'in'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'the'
# Processing word: studios
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'studios' with 'workshops'
# Processing word: quickly
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'quickly'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'paint' with 'create'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'studios': ['workshops'], 'paint': ['create'], 'pictures': ['images']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The artists who the gallery owners hire paint new pictures.
# Processing word: The
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'The'
# Processing word: artists
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'artists' with 'artists'
# Processing word: who
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'who'
# Processing word: the
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'the'
# Processing word: gallery
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'gallery'
# Processing word: owners
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'owners'
# Processing word: hire
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'hire'
# Processing word: paint
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'paint'
# Processing word: new
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Kept 'new'
# Processing word: pictures.
# Synonyms dict: {'artists': ['painters'], 'pictures': ['paintings']}
# Replaced 'pictures' with 'pictures'
#
# Processing sentence: The talented artists who read the books that were on the shelves painted their canvases yesterday.
# Processing word: The
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['colored'], 'canvases': ['artworks'], 'yesterday': ['earlier']}
# Kept 'The'
# Processing word: talented
# Synonyms dict: {'talented': ['skilled'], 'artists': ['painters'], 'painted': ['colored'], 'canvases': ['artworks'], 'yesterday': ['earlier']}
# Replaced 'talented' with 'skilled'
# ...
# Replaced 'operate' with 'operate'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'trained': ['taught'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'the'
# Processing word: buses
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'trained': ['taught'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'buses' with 'buses'
# Processing word: at
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'trained': ['taught'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'at'
# Processing word: night.
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'trained': ['taught'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'night'
#
# Processing sentence: Experienced planners who checked the maps that the analysts created operate the buses at night.
# Processing word: Experienced
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'Experienced' with 'Skilled'
# Processing word: planners
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'planners' with 'organizers'
# Processing word: who
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'who'
# Processing word: checked
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'checked'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'the'
# Processing word: maps
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'maps'
# Processing word: that
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'that'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'the'
# Processing word: analysts
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'analysts' with 'examiners'
# Processing word: created
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'created' with 'created'
# Processing word: operate
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'operate' with 'run'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'the'
# Processing word: buses
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'buses' with 'buses'
# Processing word: at
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'at'
# Processing word: night.
# Synonyms dict: {'experienced': ['skilled'], 'planners': ['organizers'], 'analysts': ['examiners'], 'created': ['produced'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'night'
#
# Processing sentence: Planners who studied traffic patterns operate the buses at night.
# Processing word: Planners
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'Planners' with 'Organizers'
# Processing word: who
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'who'
# Processing word: studied
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'studied' with 'examined'
# Processing word: traffic
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'traffic'
# Processing word: patterns
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'patterns'
# Processing word: operate
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'operate' with 'operate'
# Processing word: the
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'the'
# Processing word: buses
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Replaced 'buses' with 'buses'
# Processing word: at
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'at'
# Processing word: night.
# Synonyms dict: {'planners': ['organizers'], 'studied': ['examined'], 'operate': ['run'], 'buses': ['coaches']}
# Kept 'night'
#
# Processing sentence: The athlete who trained well hastily runs the track.
# Processing word: The
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Kept 'The'
# Processing word: athlete
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Replaced 'athlete' with 'athlete'
# Processing word: who
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Kept 'who'
# Processing word: trained
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Replaced 'trained' with 'prepared'
# Processing word: well
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Kept 'well'
# Processing word: hastily
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Replaced 'hastily' with 'hastily'
# Processing word: runs
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Replaced 'runs' with 'sprints'
# Processing word: the
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Kept 'the'
# Processing word: track.
# Synonyms dict: {'athlete': ['runner'], 'trained': ['prepared'], 'hastily': ['quickly'], 'runs': ['sprints'], 'track': ['course']}
# Replaced 'track' with 'course'
#
# Processing sentence: Planners who checked the maps that the analysts created operate the buses at night.
# Processing word: Planners
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Replaced 'Planners' with 'Planners'
# Processing word: who
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'who'
# Processing word: checked
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'checked'
# Processing word: the
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'the'
# Processing word: maps
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Replaced 'maps' with 'charts'
# Processing word: that
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'that'
# Processing word: the
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'the'
# Processing word: analysts
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Replaced 'analysts' with 'evaluators'
# Processing word: created
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Replaced 'created' with 'designed'
# Processing word: operate
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Replaced 'operate' with 'drive'
# Processing word: the
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'the'
# Processing word: buses
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'buses'
# Processing word: at
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'at'
# Processing word: night.
# Synonyms dict: {'planners': ['organizers'], 'maps': ['charts'], 'analysts': ['evaluators'], 'created': ['designed'], 'operate': ['drive']}
# Kept 'night'
#
# Processing sentence: The pilot quickly flew the plane late.
# Processing word: The
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Kept 'The'
# Processing word: pilot
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Replaced 'pilot' with 'aviator'
# Processing word: quickly
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Replaced 'quickly' with 'rapidly'
# Processing word: flew
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Replaced 'flew' with 'soared'
# Processing word: the
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Kept 'the'
# Processing word: plane
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Replaced 'plane' with 'plane'
# Processing word: late.
# Synonyms dict: {'pilot': ['aviator'], 'quickly': ['rapidly'], 'flew': ['soared'], 'plane': ['aircraft'], 'late': ['tardy']}
# Replaced 'late' with 'late'
#
# Processing sentence: Experienced planners that the engineers trained efficiently operate the buses at night.
# Processing word: Experienced
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Replaced 'Experienced' with 'Skilled'
# Processing word: planners
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'planners'
# Processing word: that
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'that'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'the'
# Processing word: engineers
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'engineers'
# Processing word: trained
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Replaced 'trained' with 'trained'
# Processing word: efficiently
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Replaced 'efficiently' with 'effectively'
# Processing word: operate
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Replaced 'operate' with 'operate'
# Processing word: the
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'the'
# Processing word: buses
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'buses'
# Processing word: at
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'at'
# Processing word: night.
# Synonyms dict: {'experienced': ['skilled'], 'planners': [], 'engineers': [], 'trained': ['prepared'], 'efficiently': ['effectively'], 'operate': ['run'], 'buses': [], 'night': []}
# Kept 'night'
#
# Processing sentence: The pilot who studied hard flew the plane late.
# Processing word: The
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Kept 'The'
# Processing word: pilot
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'pilot' with 'pilot'
# Processing word: who
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Kept 'who'
# Processing word: studied
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'studied' with 'learned'
# Processing word: hard
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'hard' with 'diligently'
# Processing word: flew
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'flew' with 'flew'
# Processing word: the
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Kept 'the'
# Processing word: plane
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'plane' with 'plane'
# Processing word: late.
# Synonyms dict: {'pilot': ['aviator'], 'studied': ['learned'], 'hard': ['diligently'], 'flew': ['piloted'], 'plane': ['aircraft'], 'late': ['tardily']}
# Replaced 'late' with 'late'

# %%
# Add timestamp to filename for versioning
output_path = Path("/home/co/git/neurospin-new-protocol/stim/sentences/V2/processed/controlled_augmented.csv")

# Save to CSV
new_df.to_csv(output_path, index=False)

print(f"Saved variations to: {output_path}")

# %%
new_df[['original_sentence', 'sentence']].head(30)
# Out:
#                                     original_sentence  \
# 0                          Customers buy the product.
# 1                  Customers eagerly buy the product.
# 2                    Happy customers buy the product.
# 3            Happy customers eagerly buy the product.
# 4              Customers on the site buy the product.
# 5      Customers on the site eagerly buy the product.
# 6        Happy customers on the site buy the product.
# 7   Happy customers on the site eagerly buy the pr...
# 8          Customers who visit daily buy the product.
# 9   Customers who visit daily eagerly buy the prod...
# 10   Happy customers who visit daily buy the product.
# 11  Happy customers who visit daily eagerly buy th...
# 12     Customers that reviews praise buy the product.
# 13  Customers that reviews praise eagerly buy the ...
# 14  Happy customers that reviews praise buy the pr...
# 15  Happy customers that reviews praise eagerly bu...
# 16  Customers who browse the section that interest...
# 17  Customers who browse the section that interest...
# 18  Happy customers who browse the section that in...
# 19  Happy customers who browse the section that in...
# 20                        Doctors treat the symptoms.
# 21               Doctors promptly treat the symptoms.
# 22              Competent doctors treat the symptoms.
# 23     Competent doctors promptly treat the symptoms.
# 24        Doctors in the hospital treat the symptoms.
# 25  Doctors in the hospital promptly treat the sym...
# 26  Competent doctors in the hospital treat the sy...
# 27  Competent doctors in the hospital promptly tre...
# 28     Doctors who study medicine treat the symptoms.
# 29  Doctors who study medicine promptly treat the ...
#
#                                              sentence
# 0                         Buyers acquire the product.
# 1                 Buyers eagerly acquire the product.
# 2                 Happy clients purchase the product.
# 3   Pleased clients enthusiastically buy the product.
# 4          Buyers on the webpage acquire the product.
# 5   Customers on the site eagerly purchase the pro...
# 6    Pleased clients on the site acquire the product.
# 7   Satisfied customers on the site enthusiastical...
# 8    Clients who frequent daily purchase the product.
# 9   Clients who visit regularly eagerly buy the pr...
# 10  Happy customers who attend daily acquire the p...
# 11  Content clients who visit everyday eagerly buy...
# 12        Buyers that reviews praise buy the product.
# 13  Customers that reviews praise eagerly buy the ...
# 14  Happy clients that critiques praise acquire th...
# 15  Happy patrons that reviews praise keenly buy t...
# 16  Customers who scan the area that attracts them...
# 17  Customers who peruse the section that engages ...
# 18  Satisfied customers who browse the section tha...
# 19  Happy clients who peruse the section that enga...
# 20                     Physicians treat the symptoms.
# 21          Physicians promptly address the symptoms.
# 22           Capable physicians address the symptoms.
# 23     Capable physicians swiftly treat the symptoms.
# 24       Physicians in the clinic treat the symptoms.
# 25  Doctors in the hospital promptly treat the sym...
# 26  Competent doctors in the hospital treat the sy...
# 27  Competent doctors in the hospital promptly tre...
# 28    Doctors who study healthcare heal the symptoms.
# 29  Doctors who learn medicine promptly treat the ...

# %% [markdown]
# # Organizer

# %% [markdown]
# TODO:
# - Make different runs for each subject, with different natural sentences for each subjects
# - Keep the same controlled sentences for all subjects
# - Keep the constraint about at least 3 natural sentences at every run start

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import random
from typing import Union, List
from openai import OpenAI

class DatasetPreparator:
    def __init__(self, naturalistic_path, controlled_path, output_dir='stim', openai_key=None):
        self.naturalistic_df = pd.read_csv(naturalistic_path)
        self.controlled_df = pd.read_csv(controlled_path)
        self.output_dir = Path(output_dir)
        self.audio_dir = self.output_dir / 'audio'
        self.openai_key = openai_key
        self.audio_dir.mkdir(parents=True, exist_ok=True)

    def generate_speech(self, row, voice: str = "alloy", model: str = "tts-1") -> Path:
        """Generate speech for a single sentence using its audio_filename"""
        if self.openai_key is None:
            raise ValueError("OpenAI API key is required for speech generation")
            
        client = OpenAI(api_key=self.openai_key)
        
        speech_file_path = self.audio_dir / row['audio_filename']
        
        if speech_file_path.exists():
            print(f"File exists: {speech_file_path}")
            return speech_file_path
            
        try:
            response = client.audio.speech.create(
                model=model,
                voice=voice,
                input=row['sentence']
            )
            response.stream_to_file(str(speech_file_path))
            print(f"Generated: {speech_file_path}")
            return speech_file_path
        except Exception as e:
            print(f"Error generating audio for: {row['sentence']}\nError: {str(e)}")
            return None
        
    def generate_all_speech(self, max_workers=5, batch_size=20, delay_between_batches=0):
        """
        Generate speech for all sentences in parallel.
        
        Args:
            max_workers (int): Maximum number of parallel workers
            batch_size (int): Number of requests to process in each batch
            delay_between_batches (int): Delay in seconds between batches to avoid rate limits
        """
        from concurrent.futures import ThreadPoolExecutor
        import time
        
        def process_batch(rows):
            results = []
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                futures = [executor.submit(self.generate_speech, row) for row in rows]
                for future in futures:
                    try:
                        result = future.result()
                        results.append(result)
                    except Exception as e:
                        print(f"Error in batch processing: {str(e)}")
                        results.append(None)
            return results

        # Split the dataframe into batches
        total_rows = len(self.final_df)
        batches = [self.final_df[i:i + batch_size] for i in range(0, total_rows, batch_size)]
        
        print(f"Processing {total_rows} sentences in {len(batches)} batches of {batch_size}")
        
        all_results = []
        for i, batch in enumerate(batches, 1):
            print(f"\nProcessing batch {i}/{len(batches)}")
            results = process_batch(batch.to_dict('records'))
            all_results.extend(results)
            
            if i < len(batches):  # Don't delay after the last batch
                print(f"Waiting {delay_between_batches} seconds before next batch...")
                time.sleep(delay_between_batches)
        
        # Count successes and failures
        successes = sum(1 for r in all_results if r is not None)
        failures = sum(1 for r in all_results if r is None)
        
        print(f"\nGeneration complete:")
        print(f"Successful generations: {successes}")
        print(f"Failed generations: {failures}")
        
        return all_results

    def prepare_controlled_data(self):
        """Prepare controlled dataset with proper columns and audio filename"""
        self.controlled_df['dataset'] = 'controlled'
        
        # Preserve the structure column
        if 'structure' not in self.controlled_df.columns:
            self.controlled_df['structure'] = None
            
        # Rename word_count to num_words if it exists
        if 'word_count' in self.controlled_df.columns:
            self.controlled_df.rename(columns={'word_count': 'num_words'}, inplace=True)
        
        # Create sentence_id for reference
        self.controlled_df['sentence_id'] = [f"ctrl_{i:05d}" for i in range(len(self.controlled_df))]
        
        # Create audio_filename using the specified format: tense_theme_plurality_variation.wav
        # self.controlled_df['audio_filename'] = self.controlled_df.apply(
        #     lambda row: f"{row['tense']}_{row['theme']}_{row['numerosity']}_{row['structure']}.wav", 
        #     axis=1
        # )
        # Create instead in the same way as the naturalistic dataset
        self.controlled_df['audio_filename'] = self.controlled_df['sentence_id'].apply(lambda x: f"{x}.wav")
        
        return self.controlled_df

    def prepare_naturalistic_data(self):
        """Prepare naturalistic dataset with sentence_id and audio filename"""
        self.naturalistic_df['dataset'] = 'naturalistic'
        self.naturalistic_df['numerosity'] = self.naturalistic_df['numer']
        self.naturalistic_df.drop('numer', axis=1, inplace=True)
        
        # Handle word count columns
        if 'word_count' in self.naturalistic_df.columns and 'num_words' not in self.naturalistic_df.columns:
            self.naturalistic_df.rename(columns={'word_count': 'num_words'}, inplace=True)
        
        self.naturalistic_df['sentence_id'] = [f"nat_{i:05d}" for i in range(len(self.naturalistic_df))]
        self.naturalistic_df['audio_filename'] = self.naturalistic_df['sentence_id'].apply(lambda x: f"{x}.wav")
        
        return self.naturalistic_df

    def create_final_dataset(self):
        """Merge datasets and adjust naturalistic sentences to make total divisible by 80"""
        naturalistic = self.prepare_naturalistic_data()
        controlled = self.prepare_controlled_data()
        
        # Ensure columns match before concatenation
        common_columns = set(naturalistic.columns) & set(controlled.columns)
        naturalistic = naturalistic[list(common_columns)]
        controlled = controlled[list(common_columns)]
        
        n_controlled = len(controlled)
        n_naturalistic = len(naturalistic)
        
        # Calculate the number of complete runs possible
        total_sentences = n_controlled + n_naturalistic
        n_complete_runs = total_sentences // 80
        
        if total_sentences % 80 != 0:
            n_complete_runs += 1
        
        total_needed = n_complete_runs * 80
        n_naturalistic_needed = total_needed - n_controlled
        
        if n_naturalistic_needed > n_naturalistic:
            n_complete_runs = (n_controlled + n_naturalistic) // 80
            total_needed = n_complete_runs * 80
            n_naturalistic_needed = total_needed - n_controlled
        
        print(f"Total runs possible: {n_complete_runs}")
        print(f"Total sentences needed: {total_needed}")
        print(f"Controlled sentences: {n_controlled}")
        print(f"Naturalistic sentences needed: {n_naturalistic_needed}")
        print(f"Naturalistic sentences available: {n_naturalistic}")
        
        # Randomly select the required number of naturalistic sentences
        naturalistic = naturalistic.sample(n=n_naturalistic_needed, random_state=42)
        
        final_df = pd.concat([naturalistic, controlled], ignore_index=True)
        return final_df

class RunOrganizer:
    def __init__(self, final_df, n_subjects=10, trials_per_run=80):
        self.final_df = final_df
        self.n_subjects = n_subjects
        self.trials_per_run = trials_per_run
        self.n_total_runs = len(final_df) // trials_per_run
        
    def create_runs(self):
        """Create runs for all subjects, where each subject gets all sentences"""
        all_runs = []
        
        # Calculate total number of runs per subject
        self.runs_per_subject = len(self.final_df) // self.trials_per_run
        
        # Create word count mapping
        self.word_counts = dict(zip(self.final_df['audio_filename'], self.final_df['num_words']))
        
        for subject in range(1, self.n_subjects + 1):
            # Get all files and shuffle them independently for each subject
            naturalistic_files = self.final_df[self.final_df['dataset'] == 'naturalistic']['audio_filename'].tolist()
            controlled_files = self.final_df[self.final_df['dataset'] == 'controlled']['audio_filename'].tolist()
            
            subject_runs = self._create_subject_runs(
                subject,
                naturalistic_files,
                controlled_files
            )
            all_runs.extend(subject_runs)
        
        # Convert to DataFrame
        runs_df = pd.DataFrame(all_runs)
        return runs_df
        
    def _create_subject_runs(self, subject, naturalistic_files, controlled_files):
        """Create all runs for a single subject using all available sentences"""
        subject_runs = []
        
        # Create pools of files that we'll draw from for each run
        remaining_naturalistic = naturalistic_files.copy()
        remaining_controlled = controlled_files.copy()
        
        for run in range(1, self.runs_per_subject + 1):
            run_sentences = []
            
            # Ensure we have enough naturalistic sentences for the start
            if len(remaining_naturalistic) < 3:
                remaining_naturalistic = naturalistic_files.copy()
            
            # Start with 3 random naturalistic sentences
            start_sentences = random.sample(remaining_naturalistic, 3)
            run_sentences.extend(start_sentences)
            for sent in start_sentences:
                remaining_naturalistic.remove(sent)
            
            # Pool for remaining sentences
            available_pool = (remaining_naturalistic + remaining_controlled).copy()
            if len(available_pool) < (self.trials_per_run - 3):
                # Replenish the pool if needed
                remaining_naturalistic = naturalistic_files.copy()
                remaining_controlled = controlled_files.copy()
                # Remove the sentences we just used at the start
                for sent in start_sentences:
                    if sent in remaining_naturalistic:
                        remaining_naturalistic.remove(sent)
                available_pool = (remaining_naturalistic + remaining_controlled).copy()
            
            # Fill the rest of the run
            remaining_needed = self.trials_per_run - 3
            
            # Select remaining sentences avoiding consecutive long sentences
            while len(run_sentences) < self.trials_per_run:
                candidates = [s for s in available_pool 
                            if not (len(run_sentences) > 0 and 
                                  self.word_counts.get(run_sentences[-1], 0) > 10 and 
                                  self.word_counts.get(s, 0) > 10)]
                
                if not candidates:
                    candidates = available_pool
                    
                selected = random.choice(candidates)
                run_sentences.append(selected)
                available_pool.remove(selected)
                
                # Update the remaining pools
                if selected in remaining_naturalistic:
                    remaining_naturalistic.remove(selected)
                elif selected in remaining_controlled:
                    remaining_controlled.remove(selected)
            
            # Create run data
            for trial, sentence in enumerate(run_sentences, 1):
                subject_runs.append({
                    'subject': subject,
                    'run': run,
                    'trial': trial,
                    'audio_filename': sentence,
                    'is_naturalistic': sentence.startswith('nat_'),
                    'num_words': self.word_counts.get(sentence, None)
                })
        
        return subject_runs

# %%
OPENAI_API_KEY = "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"
# Initialize preparator
preparator = DatasetPreparator(
    naturalistic_path='./../stim/text/1000_most_common.csv',
    controlled_path='./../stim/sentences/relatives/relatives_variations_augmented.csv',
    output_dir='./../stim',
    openai_key=OPENAI_API_KEY
)

# Create final dataset
final_df = preparator.create_final_dataset()
preparator.final_df = final_df  # Make sure final_df is accessible in the preparator

# Generate all audio files in parallel
results = preparator.generate_all_speech(
    max_workers=50,  # Number of parallel requests
    batch_size=200,  # Number of requests per batch
    delay_between_batches=0  # Delay between batches in seconds
)
# Create run organization
organizer = RunOrganizer(final_df)
runs_df = organizer.create_runs()
final_df.to_csv('./../stim/final_dataset.csv', index=False)
runs_df.to_csv('./../stim/runs_organization.csv', index=False)
# Out:
# Total runs possible: 41
# Total sentences needed: 3280
# Controlled sentences: 1200
# Naturalistic sentences needed: 2080
# Naturalistic sentences available: 2131
# Processing 3280 sentences in 17 batches of 200
#
# Processing batch 1/17
# File exists: ../stim/audio/nat_00297.wav
# File exists: ../stim/audio/nat_00282.wav
# File exists: ../stim/audio/nat_01666.wav
# File exists: ../stim/audio/nat_02066.wav
# File exists: ../stim/audio/nat_00290.wav
# File exists: ../stim/audio/nat_01713.wav
# File exists: ../stim/audio/nat_00070.wav
# File exists: ../stim/audio/nat_01745.wav
# File exists: ../stim/audio/nat_02008.wav
# File exists: ../stim/audio/nat_01708.wav
# File exists: ../stim/audio/nat_01116.wav
# File exists: ../stim/audio/nat_00650.wav
# File exists: ../stim/audio/nat_00507.wav
# File exists: ../stim/audio/nat_01721.wav
# File exists: ../stim/audio/nat_00916.wav
# File exists: ../stim/audio/nat_00450.wav
# File exists: ../stim/audio/nat_01600.wav
# File exists: ../stim/audio/nat_01932.wav
# File exists: ../stim/audio/nat_00196.wav
# File exists: ../stim/audio/nat_00298.wav
# File exists: ../stim/audio/nat_00342.wav
# File exists: ../stim/audio/nat_00109.wav
# File exists: ../stim/audio/nat_01789.wav
# File exists: ../stim/audio/nat_01834.wav
# File exists: ../stim/audio/nat_02089.wav
# File exists: ../stim/audio/nat_01827.wav
# File exists: ../stim/audio/nat_00707.wav
# File exists: ../stim/audio/nat_01258.wav
# File exists: ../stim/audio/nat_01402.wav
# File exists: ../stim/audio/nat_00111.wav
# File exists: ../stim/audio/nat_00647.wav
# File exists: ../stim/audio/nat_01573.wav
# File exists: ../stim/audio/nat_01831.wav
# File exists: ../stim/audio/nat_00306.wav
# File exists: ../stim/audio/nat_00433.wav
# File exists: ../stim/audio/nat_01413.wav
# File exists: ../stim/audio/nat_01362.wav
# File exists: ../stim/audio/nat_00321.wav
# File exists: ../stim/audio/nat_00581.wav
# File exists: ../stim/audio/nat_00771.wav
# File exists: ../stim/audio/nat_00579.wav
# File exists: ../stim/audio/nat_00367.wav
# File exists: ../stim/audio/nat_01898.wav
# File exists: ../stim/audio/nat_00952.wav
# File exists: ../stim/audio/nat_00599.wav
# File exists: ../stim/audio/nat_01904.wav
# File exists: ../stim/audio/nat_00988.wav
# File exists: ../stim/audio/nat_01879.wav
# File exists: ../stim/audio/nat_00812.wav
# File exists: ../stim/audio/nat_00471.wav
# File exists: ../stim/audio/nat_00464.wav
# File exists: ../stim/audio/nat_01259.wav
# File exists: ../stim/audio/nat_01965.wav
# File exists: ../stim/audio/nat_02021.wav
# File exists: ../stim/audio/nat_00543.wav
# File exists: ../stim/audio/nat_01106.wav
# File exists: ../stim/audio/nat_00420.wav
# File exists: ../stim/audio/nat_00670.wav
# File exists: ../stim/audio/nat_00067.wav
# File exists: ../stim/audio/nat_00620.wav
# File exists: ../stim/audio/nat_00135.wav
# File exists: ../stim/audio/nat_01425.wav
# File exists: ../stim/audio/nat_01316.wav
# File exists: ../stim/audio/nat_02060.wav
# File exists: ../stim/audio/nat_00029.wav
# File exists: ../stim/audio/nat_00128.wav
# File exists: ../stim/audio/nat_01617.wav
# File exists: ../stim/audio/nat_00637.wav
# File exists: ../stim/audio/nat_01307.wav
# File exists: ../stim/audio/nat_00585.wav
# File exists: ../stim/audio/nat_00307.wav
# File exists: ../stim/audio/nat_00184.wav
# File exists: ../stim/audio/nat_01437.wav
# File exists: ../stim/audio/nat_02065.wav
# File exists: ../stim/audio/nat_00427.wav
# File exists: ../stim/audio/nat_00900.wav
# File exists: ../stim/audio/nat_00943.wav
# File exists: ../stim/audio/nat_00422.wav
# File exists: ../stim/audio/nat_00231.wav
# File exists: ../stim/audio/nat_01961.wav
# File exists: ../stim/audio/nat_01420.wav
# File exists: ../stim/audio/nat_00836.wav
# File exists: ../stim/audio/nat_00426.wav
# File exists: ../stim/audio/nat_01333.wav
# File exists: ../stim/audio/nat_01554.wav
# File exists: ../stim/audio/nat_00948.wav
# File exists: ../stim/audio/nat_00482.wav
# File exists: ../stim/audio/nat_00051.wav
# File exists: ../stim/audio/nat_01004.wav
# File exists: ../stim/audio/nat_01567.wav
# File exists: ../stim/audio/nat_01229.wav
# File exists: ../stim/audio/nat_00324.wav
# File exists: ../stim/audio/nat_00649.wav
# File exists: ../stim/audio/nat_01383.wav
# File exists: ../stim/audio/nat_01499.wav
# File exists: ../stim/audio/nat_00529.wav
# File exists: ../stim/audio/nat_01883.wav
# File exists: ../stim/audio/nat_01542.wav
# File exists: ../stim/audio/nat_01635.wav
# File exists: ../stim/audio/nat_00409.wav
# File exists: ../stim/audio/nat_00254.wav
# File exists: ../stim/audio/nat_00485.wav
# File exists: ../stim/audio/nat_00259.wav
# File exists: ../stim/audio/nat_01084.wav
# File exists: ../stim/audio/nat_00993.wav
# File exists: ../stim/audio/nat_01034.wav
# File exists: ../stim/audio/nat_01442.wav
# File exists: ../stim/audio/nat_00408.wav
# File exists: ../stim/audio/nat_00251.wav
# File exists: ../stim/audio/nat_01852.wav
# File exists: ../stim/audio/nat_00211.wav
# File exists: ../stim/audio/nat_00100.wav
# File exists: ../stim/audio/nat_00678.wav
# File exists: ../stim/audio/nat_01950.wav
# File exists: ../stim/audio/nat_01387.wav
# File exists: ../stim/audio/nat_00590.wav
# File exists: ../stim/audio/nat_00530.wav
# File exists: ../stim/audio/nat_01151.wav
# File exists: ../stim/audio/nat_00630.wav
# File exists: ../stim/audio/nat_01273.wav
# File exists: ../stim/audio/nat_01623.wav
# File exists: ../stim/audio/nat_01359.wav
# File exists: ../stim/audio/nat_00561.wav
# File exists: ../stim/audio/nat_01773.wav
# File exists: ../stim/audio/nat_02059.wav
# File exists: ../stim/audio/nat_01432.wav
# File exists: ../stim/audio/nat_00610.wav
# File exists: ../stim/audio/nat_01460.wav
# File exists: ../stim/audio/nat_01657.wav
# File exists: ../stim/audio/nat_01760.wav
# File exists: ../stim/audio/nat_00247.wav
# File exists: ../stim/audio/nat_00275.wav
# File exists: ../stim/audio/nat_01626.wav
# File exists: ../stim/audio/nat_01403.wav
# File exists: ../stim/audio/nat_00538.wav
# File exists: ../stim/audio/nat_00056.wav
# File exists: ../stim/audio/nat_01580.wav
# File exists: ../stim/audio/nat_00120.wav
# File exists: ../stim/audio/nat_00240.wav
# File exists: ../stim/audio/nat_01730.wav
# File exists: ../stim/audio/nat_01779.wav
# File exists: ../stim/audio/nat_02017.wav
# File exists: ../stim/audio/nat_00978.wav
# File exists: ../stim/audio/nat_00410.wav
# File exists: ../stim/audio/nat_00535.wav
# File exists: ../stim/audio/nat_01336.wav
# File exists: ../stim/audio/nat_02000.wav
# File exists: ../stim/audio/nat_00861.wav
# File exists: ../stim/audio/nat_01921.wav
# File exists: ../stim/audio/nat_00712.wav
# File exists: ../stim/audio/nat_01993.wav
# File exists: ../stim/audio/nat_00564.wav
# File exists: ../stim/audio/nat_01936.wav
# File exists: ../stim/audio/nat_01572.wav
# File exists: ../stim/audio/nat_01342.wav
# File exists: ../stim/audio/nat_00596.wav
# File exists: ../stim/audio/nat_00069.wav
# File exists: ../stim/audio/nat_00544.wav
# File exists: ../stim/audio/nat_02123.wav
# File exists: ../stim/audio/nat_00233.wav
# File exists: ../stim/audio/nat_00458.wav
# File exists: ../stim/audio/nat_00486.wav
# File exists: ../stim/audio/nat_01114.wav
# File exists: ../stim/audio/nat_01511.wav
# File exists: ../stim/audio/nat_00752.wav
# File exists: ../stim/audio/nat_00350.wav
# File exists: ../stim/audio/nat_01618.wav
# File exists: ../stim/audio/nat_00719.wav
# File exists: ../stim/audio/nat_00438.wav
# File exists: ../stim/audio/nat_01601.wav
# File exists: ../stim/audio/nat_01832.wav
# File exists: ../stim/audio/nat_01128.wav
# File exists: ../stim/audio/nat_01642.wav
# File exists: ../stim/audio/nat_00483.wav
# File exists: ../stim/audio/nat_02067.wav
# File exists: ../stim/audio/nat_01357.wav
# File exists: ../stim/audio/nat_02054.wav
# File exists: ../stim/audio/nat_00921.wav
# File exists: ../stim/audio/nat_01867.wav
# File exists: ../stim/audio/nat_00695.wav
# File exists: ../stim/audio/nat_01467.wav
# File exists: ../stim/audio/nat_01927.wav
# File exists: ../stim/audio/nat_01503.wav
# File exists: ../stim/audio/nat_02011.wav
# File exists: ../stim/audio/nat_01298.wav
# File exists: ../stim/audio/nat_01649.wav
# File exists: ../stim/audio/nat_01271.wav
# File exists: ../stim/audio/nat_00099.wav
# File exists: ../stim/audio/nat_00281.wav
# File exists: ../stim/audio/nat_00299.wav
# File exists: ../stim/audio/nat_00239.wav
# File exists: ../stim/audio/nat_01637.wav
# File exists: ../stim/audio/nat_00893.wav
# File exists: ../stim/audio/nat_00818.wav
# File exists: ../stim/audio/nat_02122.wav
# File exists: ../stim/audio/nat_01505.wav
# File exists: ../stim/audio/nat_00495.wav
# File exists: ../stim/audio/nat_01283.wav
# File exists: ../stim/audio/nat_01703.wav
# File exists: ../stim/audio/nat_00124.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 2/17
# File exists: ../stim/audio/nat_01602.wav
# File exists: ../stim/audio/nat_01935.wav
# File exists: ../stim/audio/nat_01970.wav
# File exists: ../stim/audio/nat_02055.wav
# File exists: ../stim/audio/nat_00065.wav
# File exists: ../stim/audio/nat_01232.wav
# File exists: ../stim/audio/nat_01414.wav
# File exists: ../stim/audio/nat_01803.wav
# File exists: ../stim/audio/nat_01651.wav
# File exists: ../stim/audio/nat_00686.wav
# File exists: ../stim/audio/nat_00354.wav
# File exists: ../stim/audio/nat_01087.wav
# File exists: ../stim/audio/nat_00806.wav
# File exists: ../stim/audio/nat_01656.wav
# File exists: ../stim/audio/nat_01628.wav
# File exists: ../stim/audio/nat_01061.wav
# File exists: ../stim/audio/nat_01421.wav
# File exists: ../stim/audio/nat_00602.wav
# File exists: ../stim/audio/nat_01176.wav
# File exists: ../stim/audio/nat_00636.wav
# File exists: ../stim/audio/nat_00617.wav
# File exists: ../stim/audio/nat_01545.wav
# File exists: ../stim/audio/nat_00925.wav
# File exists: ../stim/audio/nat_01468.wav
# File exists: ../stim/audio/nat_01611.wav
# File exists: ../stim/audio/nat_00674.wav
# File exists: ../stim/audio/nat_00185.wav
# File exists: ../stim/audio/nat_01616.wav
# File exists: ../stim/audio/nat_01125.wav
# File exists: ../stim/audio/nat_00096.wav
# File exists: ../stim/audio/nat_01221.wav
# File exists: ../stim/audio/nat_00134.wav
# File exists: ../stim/audio/nat_01385.wav
# File exists: ../stim/audio/nat_02026.wav
# File exists: ../stim/audio/nat_01364.wav
# File exists: ../stim/audio/nat_01200.wav
# File exists: ../stim/audio/nat_01068.wav
# File exists: ../stim/audio/nat_01330.wav
# File exists: ../stim/audio/nat_00212.wav
# File exists: ../stim/audio/nat_01332.wav
# File exists: ../stim/audio/nat_01559.wav
# File exists: ../stim/audio/nat_01064.wav
# File exists: ../stim/audio/nat_02051.wav
# File exists: ../stim/audio/nat_00440.wav
# File exists: ../stim/audio/nat_02023.wav
# File exists: ../stim/audio/nat_01204.wav
# File exists: ../stim/audio/nat_01285.wav
# File exists: ../stim/audio/nat_00845.wav
# File exists: ../stim/audio/nat_00188.wav
# File exists: ../stim/audio/nat_00220.wav
# File exists: ../stim/audio/nat_00210.wav
# File exists: ../stim/audio/nat_01134.wav
# File exists: ../stim/audio/nat_02128.wav
# File exists: ../stim/audio/nat_01464.wav
# File exists: ../stim/audio/nat_00289.wav
# File exists: ../stim/audio/nat_00694.wav
# File exists: ../stim/audio/nat_00721.wav
# File exists: ../stim/audio/nat_00567.wav
# File exists: ../stim/audio/nat_00810.wav
# File exists: ../stim/audio/nat_01723.wav
# File exists: ../stim/audio/nat_00013.wav
# File exists: ../stim/audio/nat_01737.wav
# File exists: ../stim/audio/nat_00237.wav
# File exists: ../stim/audio/nat_01422.wav
# File exists: ../stim/audio/nat_01395.wav
# File exists: ../stim/audio/nat_00809.wav
# File exists: ../stim/audio/nat_01001.wav
# File exists: ../stim/audio/nat_01189.wav
# File exists: ../stim/audio/nat_01692.wav
# File exists: ../stim/audio/nat_00478.wav
# File exists: ../stim/audio/nat_01394.wav
# File exists: ../stim/audio/nat_00416.wav
# File exists: ../stim/audio/nat_01052.wav
# File exists: ../stim/audio/nat_01441.wav
# File exists: ../stim/audio/nat_01345.wav
# File exists: ../stim/audio/nat_00316.wav
# File exists: ../stim/audio/nat_02084.wav
# File exists: ../stim/audio/nat_02022.wav
# File exists: ../stim/audio/nat_02016.wav
# File exists: ../stim/audio/nat_01360.wav
# File exists: ../stim/audio/nat_01427.wav
# File exists: ../stim/audio/nat_00867.wav
# File exists: ../stim/audio/nat_00756.wav
# File exists: ../stim/audio/nat_00121.wav
# File exists: ../stim/audio/nat_01907.wav
# File exists: ../stim/audio/nat_00874.wav
# File exists: ../stim/audio/nat_01000.wav
# File exists: ../stim/audio/nat_00862.wav
# File exists: ../stim/audio/nat_01818.wav
# File exists: ../stim/audio/nat_00888.wav
# File exists: ../stim/audio/nat_00508.wav
# File exists: ../stim/audio/nat_01073.wav
# File exists: ../stim/audio/nat_01674.wav
# File exists: ../stim/audio/nat_01820.wav
# File exists: ../stim/audio/nat_00479.wav
# File exists: ../stim/audio/nat_00965.wav
# File exists: ../stim/audio/nat_01741.wav
# File exists: ../stim/audio/nat_00705.wav
# File exists: ../stim/audio/nat_01261.wav
# File exists: ../stim/audio/nat_00966.wav
# File exists: ../stim/audio/nat_01798.wav
# File exists: ../stim/audio/nat_00746.wav
# File exists: ../stim/audio/nat_00982.wav
# File exists: ../stim/audio/nat_01117.wav
# File exists: ../stim/audio/nat_00115.wav
# File exists: ../stim/audio/nat_01526.wav
# File exists: ../stim/audio/nat_01854.wav
# File exists: ../stim/audio/nat_01998.wav
# File exists: ../stim/audio/nat_01506.wav
# File exists: ../stim/audio/nat_01477.wav
# File exists: ../stim/audio/nat_01036.wav
# File exists: ../stim/audio/nat_00942.wav
# File exists: ../stim/audio/nat_01284.wav
# File exists: ../stim/audio/nat_01952.wav
# File exists: ../stim/audio/nat_01928.wav
# File exists: ../stim/audio/nat_01085.wav
# File exists: ../stim/audio/nat_01608.wav
# File exists: ../stim/audio/nat_01463.wav
# File exists: ../stim/audio/nat_01795.wav
# File exists: ../stim/audio/nat_01058.wav
# File exists: ../stim/audio/nat_01405.wav
# File exists: ../stim/audio/nat_00368.wav
# File exists: ../stim/audio/nat_00063.wav
# File exists: ../stim/audio/nat_00903.wav
# File exists: ../stim/audio/nat_01877.wav
# File exists: ../stim/audio/nat_01454.wav
# File exists: ../stim/audio/nat_00383.wav
# File exists: ../stim/audio/nat_00445.wav
# File exists: ../stim/audio/nat_01543.wav
# File exists: ../stim/audio/nat_01113.wav
# File exists: ../stim/audio/nat_00787.wav
# File exists: ../stim/audio/nat_01044.wav
# File exists: ../stim/audio/nat_01094.wav
# File exists: ../stim/audio/nat_00382.wav
# File exists: ../stim/audio/nat_00023.wav
# File exists: ../stim/audio/nat_01668.wav
# File exists: ../stim/audio/nat_00332.wav
# File exists: ../stim/audio/nat_00963.wav
# File exists: ../stim/audio/nat_02058.wav
# File exists: ../stim/audio/nat_01769.wav
# File exists: ../stim/audio/nat_01914.wav
# File exists: ../stim/audio/nat_01374.wav
# File exists: ../stim/audio/nat_00930.wav
# File exists: ../stim/audio/nat_01845.wav
# File exists: ../stim/audio/nat_01889.wav
# File exists: ../stim/audio/nat_00049.wav
# File exists: ../stim/audio/nat_00361.wav
# File exists: ../stim/audio/nat_00429.wav
# File exists: ../stim/audio/nat_01679.wav
# File exists: ../stim/audio/nat_01553.wav
# File exists: ../stim/audio/nat_01269.wav
# File exists: ../stim/audio/nat_01175.wav
# File exists: ../stim/audio/nat_01278.wav
# File exists: ../stim/audio/nat_00840.wav
# File exists: ../stim/audio/nat_02007.wav
# File exists: ../stim/audio/nat_00817.wav
# File exists: ../stim/audio/nat_00173.wav
# File exists: ../stim/audio/nat_01391.wav
# File exists: ../stim/audio/nat_00198.wav
# File exists: ../stim/audio/nat_00838.wav
# File exists: ../stim/audio/nat_01029.wav
# File exists: ../stim/audio/nat_01840.wav
# File exists: ../stim/audio/nat_01446.wav
# File exists: ../stim/audio/nat_00873.wav
# File exists: ../stim/audio/nat_01237.wav
# File exists: ../stim/audio/nat_00583.wav
# File exists: ../stim/audio/nat_00782.wav
# File exists: ../stim/audio/nat_01047.wav
# File exists: ../stim/audio/nat_00387.wav
# File exists: ../stim/audio/nat_00071.wav
# File exists: ../stim/audio/nat_00937.wav
# File exists: ../stim/audio/nat_00381.wav
# File exists: ../stim/audio/nat_01146.wav
# File exists: ../stim/audio/nat_01208.wav
# File exists: ../stim/audio/nat_01664.wav
# File exists: ../stim/audio/nat_01544.wav
# File exists: ../stim/audio/nat_01824.wav
# File exists: ../stim/audio/nat_00256.wav
# File exists: ../stim/audio/nat_00923.wav
# File exists: ../stim/audio/nat_00998.wav
# File exists: ../stim/audio/nat_01431.wav
# File exists: ../stim/audio/nat_01847.wav
# File exists: ../stim/audio/nat_01161.wav
# File exists: ../stim/audio/nat_01202.wav
# File exists: ../stim/audio/nat_01102.wav
# File exists: ../stim/audio/nat_02118.wav
# File exists: ../stim/audio/nat_01857.wav
# File exists: ../stim/audio/nat_00892.wav
# File exists: ../stim/audio/nat_00743.wav
# File exists: ../stim/audio/nat_01814.wav
# File exists: ../stim/audio/nat_00270.wav
# File exists: ../stim/audio/nat_01996.wav
# File exists: ../stim/audio/nat_01799.wav
# File exists: ../stim/audio/nat_00374.wav
# File exists: ../stim/audio/nat_01041.wav
# File exists: ../stim/audio/nat_00020.wav
# File exists: ../stim/audio/nat_02057.wav
# File exists: ../stim/audio/nat_01474.wav
# File exists: ../stim/audio/nat_00554.wav
# File exists: ../stim/audio/nat_01625.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 3/17
# File exists: ../stim/audio/nat_00808.wav
# File exists: ../stim/audio/nat_00025.wav
# File exists: ../stim/audio/nat_01555.wav
# File exists: ../stim/audio/nat_01481.wav
# File exists: ../stim/audio/nat_01411.wav
# File exists: ../stim/audio/nat_00078.wav
# File exists: ../stim/audio/nat_00032.wav
# File exists: ../stim/audio/nat_00532.wav
# File exists: ../stim/audio/nat_01351.wav
# File exists: ../stim/audio/nat_01412.wav
# File exists: ../stim/audio/nat_00366.wav
# File exists: ../stim/audio/nat_00605.wav
# File exists: ../stim/audio/nat_00163.wav
# File exists: ../stim/audio/nat_00527.wav
# File exists: ../stim/audio/nat_01089.wav
# File exists: ../stim/audio/nat_00203.wav
# File exists: ../stim/audio/nat_00552.wav
# File exists: ../stim/audio/nat_00432.wav
# File exists: ../stim/audio/nat_00889.wav
# File exists: ../stim/audio/nat_01091.wav
# File exists: ../stim/audio/nat_01816.wav
# File exists: ../stim/audio/nat_00613.wav
# File exists: ../stim/audio/nat_01933.wav
# File exists: ../stim/audio/nat_00192.wav
# File exists: ../stim/audio/nat_00480.wav
# File exists: ../stim/audio/nat_00668.wav
# File exists: ../stim/audio/nat_01010.wav
# File exists: ../stim/audio/nat_02113.wav
# File exists: ../stim/audio/nat_00588.wav
# File exists: ../stim/audio/nat_01532.wav
# File exists: ../stim/audio/nat_00305.wav
# File exists: ../stim/audio/nat_00351.wav
# File exists: ../stim/audio/nat_01393.wav
# File exists: ../stim/audio/nat_01593.wav
# File exists: ../stim/audio/nat_02042.wav
# File exists: ../stim/audio/nat_00218.wav
# File exists: ../stim/audio/nat_01050.wav
# File exists: ../stim/audio/nat_01838.wav
# File exists: ../stim/audio/nat_02096.wav
# File exists: ../stim/audio/nat_02052.wav
# File exists: ../stim/audio/nat_01647.wav
# File exists: ../stim/audio/nat_00411.wav
# File exists: ../stim/audio/nat_01712.wav
# File exists: ../stim/audio/nat_00651.wav
# File exists: ../stim/audio/nat_00059.wav
# File exists: ../stim/audio/nat_01984.wav
# File exists: ../stim/audio/nat_00447.wav
# File exists: ../stim/audio/nat_00162.wav
# File exists: ../stim/audio/nat_01670.wav
# File exists: ../stim/audio/nat_00829.wav
# File exists: ../stim/audio/nat_00710.wav
# File exists: ../stim/audio/nat_00073.wav
# File exists: ../stim/audio/nat_01777.wav
# File exists: ../stim/audio/nat_00353.wav
# File exists: ../stim/audio/nat_00680.wav
# File exists: ../stim/audio/nat_02119.wav
# File exists: ../stim/audio/nat_01609.wav
# File exists: ../stim/audio/nat_01607.wav
# File exists: ../stim/audio/nat_01170.wav
# File exists: ../stim/audio/nat_00294.wav
# File exists: ../stim/audio/nat_01582.wav
# File exists: ../stim/audio/nat_00045.wav
# File exists: ../stim/audio/nat_01361.wav
# File exists: ../stim/audio/nat_01988.wav
# File exists: ../stim/audio/nat_00519.wav
# File exists: ../stim/audio/nat_01594.wav
# File exists: ../stim/audio/nat_00914.wav
# File exists: ../stim/audio/nat_00819.wav
# File exists: ../stim/audio/nat_00816.wav
# File exists: ../stim/audio/nat_00205.wav
# File exists: ../stim/audio/nat_00414.wav
# File exists: ../stim/audio/nat_00618.wav
# File exists: ../stim/audio/nat_02108.wav
# File exists: ../stim/audio/nat_02049.wav
# File exists: ../stim/audio/nat_01105.wav
# File exists: ../stim/audio/nat_01561.wav
# File exists: ../stim/audio/nat_00393.wav
# File exists: ../stim/audio/nat_00030.wav
# File exists: ../stim/audio/nat_01746.wav
# File exists: ../stim/audio/nat_01727.wav
# File exists: ../stim/audio/nat_00973.wav
# File exists: ../stim/audio/nat_00741.wav
# File exists: ../stim/audio/nat_00944.wav
# File exists: ../stim/audio/nat_00831.wav
# File exists: ../stim/audio/nat_01687.wav
# File exists: ../stim/audio/nat_01549.wav
# File exists: ../stim/audio/nat_00494.wav
# File exists: ../stim/audio/nat_01239.wav
# File exists: ../stim/audio/nat_00436.wav
# File exists: ../stim/audio/nat_01953.wav
# File exists: ../stim/audio/nat_00764.wav
# File exists: ../stim/audio/nat_01886.wav
# File exists: ../stim/audio/nat_00076.wav
# File exists: ../stim/audio/nat_01770.wav
# File exists: ../stim/audio/nat_01027.wav
# File exists: ../stim/audio/nat_00044.wav
# File exists: ../stim/audio/nat_01752.wav
# File exists: ../stim/audio/nat_01005.wav
# File exists: ../stim/audio/nat_01599.wav
# File exists: ../stim/audio/nat_00344.wav
# File exists: ../stim/audio/nat_00352.wav
# File exists: ../stim/audio/nat_01658.wav
# File exists: ../stim/audio/nat_01583.wav
# File exists: ../stim/audio/nat_01419.wav
# File exists: ../stim/audio/nat_00303.wav
# File exists: ../stim/audio/nat_00168.wav
# File exists: ../stim/audio/nat_02092.wav
# File exists: ../stim/audio/nat_00091.wav
# File exists: ../stim/audio/nat_01547.wav
# File exists: ../stim/audio/nat_02004.wav
# File exists: ../stim/audio/nat_01033.wav
# File exists: ../stim/audio/nat_00548.wav
# File exists: ../stim/audio/nat_00715.wav
# File exists: ../stim/audio/nat_00315.wav
# File exists: ../stim/audio/nat_01404.wav
# File exists: ../stim/audio/nat_00534.wav
# File exists: ../stim/audio/nat_01340.wav
# File exists: ../stim/audio/nat_00453.wav
# File exists: ../stim/audio/nat_00175.wav
# File exists: ../stim/audio/nat_01596.wav
# File exists: ../stim/audio/nat_01790.wav
# File exists: ../stim/audio/nat_00300.wav
# File exists: ../stim/audio/nat_01546.wav
# File exists: ../stim/audio/nat_00611.wav
# File exists: ../stim/audio/nat_00394.wav
# File exists: ../stim/audio/nat_00788.wav
# File exists: ../stim/audio/nat_00039.wav
# File exists: ../stim/audio/nat_00849.wav
# File exists: ../stim/audio/nat_00322.wav
# File exists: ../stim/audio/nat_01861.wav
# File exists: ../stim/audio/nat_00514.wav
# File exists: ../stim/audio/nat_00266.wav
# File exists: ../stim/audio/nat_00807.wav
# File exists: ../stim/audio/nat_01103.wav
# File exists: ../stim/audio/nat_00857.wav
# File exists: ../stim/audio/nat_00979.wav
# File exists: ../stim/audio/nat_00462.wav
# File exists: ../stim/audio/nat_00194.wav
# File exists: ../stim/audio/nat_00555.wav
# File exists: ../stim/audio/nat_01133.wav
# File exists: ../stim/audio/nat_01071.wav
# File exists: ../stim/audio/nat_00841.wav
# File exists: ../stim/audio/nat_01613.wav
# File exists: ../stim/audio/nat_00261.wav
# File exists: ../stim/audio/nat_01985.wav
# File exists: ../stim/audio/nat_00331.wav
# File exists: ../stim/audio/nat_00572.wav
# File exists: ../stim/audio/nat_00123.wav
# File exists: ../stim/audio/nat_01067.wav
# File exists: ../stim/audio/nat_02056.wav
# File exists: ../stim/audio/nat_01706.wav
# File exists: ../stim/audio/nat_01758.wav
# File exists: ../stim/audio/nat_01772.wav
# File exists: ../stim/audio/nat_00785.wav
# File exists: ../stim/audio/nat_02019.wav
# File exists: ../stim/audio/nat_01299.wav
# File exists: ../stim/audio/nat_01493.wav
# File exists: ../stim/audio/nat_00856.wav
# File exists: ../stim/audio/nat_01809.wav
# File exists: ../stim/audio/nat_01090.wav
# File exists: ../stim/audio/nat_01892.wav
# File exists: ../stim/audio/nat_01112.wav
# File exists: ../stim/audio/nat_01211.wav
# File exists: ../stim/audio/nat_00365.wav
# File exists: ../stim/audio/nat_01247.wav
# File exists: ../stim/audio/nat_00679.wav
# File exists: ../stim/audio/nat_00634.wav
# File exists: ../stim/audio/nat_01552.wav
# File exists: ../stim/audio/nat_01124.wav
# File exists: ../stim/audio/nat_00759.wav
# File exists: ../stim/audio/nat_00318.wav
# File exists: ../stim/audio/nat_01517.wav
# File exists: ../stim/audio/nat_00582.wav
# File exists: ../stim/audio/nat_01942.wav
# File exists: ../stim/audio/nat_01823.wav
# File exists: ../stim/audio/nat_01083.wav
# File exists: ../stim/audio/nat_00571.wav
# File exists: ../stim/audio/nat_01120.wav
# File exists: ../stim/audio/nat_01376.wav
# File exists: ../stim/audio/nat_01423.wav
# File exists: ../stim/audio/nat_01916.wav
# File exists: ../stim/audio/nat_00990.wav
# File exists: ../stim/audio/nat_00398.wav
# File exists: ../stim/audio/nat_00292.wav
# File exists: ../stim/audio/nat_00343.wav
# File exists: ../stim/audio/nat_00141.wav
# File exists: ../stim/audio/nat_01220.wav
# File exists: ../stim/audio/nat_00584.wav
# File exists: ../stim/audio/nat_01223.wav
# File exists: ../stim/audio/nat_00767.wav
# File exists: ../stim/audio/nat_00376.wav
# File exists: ../stim/audio/nat_00265.wav
# File exists: ../stim/audio/nat_00339.wav
# File exists: ../stim/audio/nat_00781.wav
# File exists: ../stim/audio/nat_00002.wav
# File exists: ../stim/audio/nat_01242.wav
# File exists: ../stim/audio/nat_01292.wav
# File exists: ../stim/audio/nat_01925.wav
# File exists: ../stim/audio/nat_00576.wav
# File exists: ../stim/audio/nat_01810.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 4/17
# File exists: ../stim/audio/nat_00271.wav
# File exists: ../stim/audio/nat_02101.wav
# File exists: ../stim/audio/nat_01833.wav
# File exists: ../stim/audio/nat_00439.wav
# File exists: ../stim/audio/nat_01476.wav
# File exists: ../stim/audio/nat_00415.wav
# File exists: ../stim/audio/nat_00727.wav
# File exists: ../stim/audio/nat_00909.wav
# File exists: ../stim/audio/nat_00244.wav
# File exists: ../stim/audio/nat_00607.wav
# File exists: ../stim/audio/nat_00250.wav
# File exists: ../stim/audio/nat_01222.wav
# File exists: ../stim/audio/nat_00413.wav
# File exists: ../stim/audio/nat_00273.wav
# File exists: ../stim/audio/nat_01110.wav
# File exists: ../stim/audio/nat_01910.wav
# File exists: ../stim/audio/nat_00736.wav
# File exists: ../stim/audio/nat_01483.wav
# File exists: ../stim/audio/nat_00425.wav
# File exists: ../stim/audio/nat_02100.wav
# File exists: ../stim/audio/nat_01665.wav
# File exists: ../stim/audio/nat_01645.wav
# File exists: ../stim/audio/nat_00865.wav
# File exists: ../stim/audio/nat_01919.wav
# File exists: ../stim/audio/nat_00310.wav
# File exists: ../stim/audio/nat_01654.wav
# File exists: ../stim/audio/nat_01513.wav
# File exists: ../stim/audio/nat_01379.wav
# File exists: ../stim/audio/nat_00170.wav
# File exists: ../stim/audio/nat_00526.wav
# File exists: ../stim/audio/nat_00619.wav
# File exists: ../stim/audio/nat_01837.wav
# File exists: ../stim/audio/nat_00693.wav
# File exists: ../stim/audio/nat_00158.wav
# File exists: ../stim/audio/nat_00187.wav
# File exists: ../stim/audio/nat_00905.wav
# File exists: ../stim/audio/nat_00272.wav
# File exists: ../stim/audio/nat_00859.wav
# File exists: ../stim/audio/nat_01080.wav
# File exists: ../stim/audio/nat_01159.wav
# File exists: ../stim/audio/nat_00786.wav
# File exists: ../stim/audio/nat_00222.wav
# File exists: ../stim/audio/nat_00182.wav
# File exists: ../stim/audio/nat_00614.wav
# File exists: ../stim/audio/nat_00371.wav
# File exists: ../stim/audio/nat_01386.wav
# File exists: ../stim/audio/nat_01726.wav
# File exists: ../stim/audio/nat_00518.wav
# File exists: ../stim/audio/nat_00593.wav
# File exists: ../stim/audio/nat_01689.wav
# File exists: ../stim/audio/nat_00755.wav
# File exists: ../stim/audio/nat_01177.wav
# File exists: ../stim/audio/nat_01771.wav
# File exists: ../stim/audio/nat_01944.wav
# File exists: ../stim/audio/nat_00744.wav
# File exists: ../stim/audio/nat_00334.wav
# File exists: ../stim/audio/nat_01947.wav
# File exists: ../stim/audio/nat_00015.wav
# File exists: ../stim/audio/nat_02063.wav
# File exists: ../stim/audio/nat_00654.wav
# File exists: ../stim/audio/nat_00570.wav
# File exists: ../stim/audio/nat_01875.wav
# File exists: ../stim/audio/nat_01163.wav
# File exists: ../stim/audio/nat_00199.wav
# File exists: ../stim/audio/nat_00465.wav
# File exists: ../stim/audio/nat_01429.wav
# File exists: ../stim/audio/nat_01181.wav
# File exists: ../stim/audio/nat_01343.wav
# File exists: ../stim/audio/nat_01453.wav
# File exists: ../stim/audio/nat_01040.wav
# File exists: ../stim/audio/nat_00043.wav
# File exists: ../stim/audio/nat_01488.wav
# File exists: ../stim/audio/nat_01018.wav
# File exists: ../stim/audio/nat_01581.wav
# File exists: ../stim/audio/nat_02003.wav
# File exists: ../stim/audio/nat_00591.wav
# File exists: ../stim/audio/nat_01263.wav
# File exists: ../stim/audio/nat_01043.wav
# File exists: ../stim/audio/nat_01424.wav
# File exists: ../stim/audio/nat_01564.wav
# File exists: ../stim/audio/nat_00915.wav
# File exists: ../stim/audio/nat_00985.wav
# File exists: ../stim/audio/nat_01225.wav
# File exists: ../stim/audio/nat_00107.wav
# File exists: ../stim/audio/nat_00101.wav
# File exists: ../stim/audio/nat_00274.wav
# File exists: ../stim/audio/nat_01013.wav
# File exists: ../stim/audio/nat_01053.wav
# File exists: ../stim/audio/nat_01190.wav
# File exists: ../stim/audio/nat_00072.wav
# File exists: ../stim/audio/nat_01869.wav
# File exists: ../stim/audio/nat_01473.wav
# File exists: ../stim/audio/nat_01235.wav
# File exists: ../stim/audio/nat_01447.wav
# File exists: ../stim/audio/nat_02121.wav
# File exists: ../stim/audio/nat_00497.wav
# File exists: ../stim/audio/nat_00765.wav
# File exists: ../stim/audio/nat_00780.wav
# File exists: ../stim/audio/nat_01694.wav
# File exists: ../stim/audio/nat_01591.wav
# File exists: ../stim/audio/nat_00907.wav
# File exists: ../stim/audio/nat_01107.wav
# File exists: ../stim/audio/nat_01301.wav
# File exists: ../stim/audio/nat_01435.wav
# File exists: ../stim/audio/nat_01389.wav
# File exists: ../stim/audio/nat_00939.wav
# File exists: ../stim/audio/nat_00506.wav
# File exists: ../stim/audio/nat_01987.wav
# File exists: ../stim/audio/nat_01846.wav
# File exists: ../stim/audio/nat_00940.wav
# File exists: ../stim/audio/nat_01471.wav
# File exists: ../stim/audio/nat_01878.wav
# File exists: ../stim/audio/nat_01891.wav
# File exists: ../stim/audio/nat_00481.wav
# File exists: ../stim/audio/nat_01680.wav
# File exists: ../stim/audio/nat_01817.wav
# File exists: ../stim/audio/nat_02005.wav
# File exists: ../stim/audio/nat_02125.wav
# File exists: ../stim/audio/nat_02064.wav
# File exists: ../stim/audio/nat_00886.wav
# File exists: ../stim/audio/nat_01023.wav
# File exists: ../stim/audio/nat_00704.wav
# File exists: ../stim/audio/nat_00311.wav
# File exists: ../stim/audio/nat_00291.wav
# File exists: ../stim/audio/nat_01778.wav
# File exists: ../stim/audio/nat_01344.wav
# File exists: ../stim/audio/nat_00906.wav
# File exists: ../stim/audio/nat_01812.wav
# File exists: ../stim/audio/nat_00405.wav
# File exists: ../stim/audio/nat_01378.wav
# File exists: ../stim/audio/nat_00148.wav
# File exists: ../stim/audio/nat_00772.wav
# File exists: ../stim/audio/nat_01381.wav
# File exists: ../stim/audio/nat_01776.wav
# File exists: ../stim/audio/nat_02020.wav
# File exists: ../stim/audio/nat_01541.wav
# File exists: ../stim/audio/nat_00692.wav
# File exists: ../stim/audio/nat_00869.wav
# File exists: ../stim/audio/nat_00226.wav
# File exists: ../stim/audio/nat_01518.wav
# File exists: ../stim/audio/nat_00309.wav
# File exists: ../stim/audio/nat_00575.wav
# File exists: ../stim/audio/nat_01784.wav
# File exists: ../stim/audio/nat_01037.wav
# File exists: ../stim/audio/nat_00701.wav
# File exists: ../stim/audio/nat_01289.wav
# File exists: ../stim/audio/nat_01187.wav
# File exists: ../stim/audio/nat_01302.wav
# File exists: ../stim/audio/nat_00628.wav
# File exists: ../stim/audio/nat_00557.wav
# File exists: ../stim/audio/nat_00167.wav
# File exists: ../stim/audio/nat_01137.wav
# File exists: ../stim/audio/nat_01309.wav
# File exists: ../stim/audio/nat_00286.wav
# File exists: ../stim/audio/nat_01234.wav
# File exists: ../stim/audio/nat_01370.wav
# File exists: ../stim/audio/nat_01983.wav
# File exists: ../stim/audio/nat_01766.wav
# File exists: ../stim/audio/nat_01318.wav
# File exists: ../stim/audio/nat_00997.wav
# File exists: ../stim/audio/nat_00730.wav
# File exists: ../stim/audio/nat_00598.wav
# File exists: ../stim/audio/nat_01169.wav
# File exists: ../stim/audio/nat_00792.wav
# File exists: ../stim/audio/nat_01165.wav
# File exists: ../stim/audio/nat_01584.wav
# File exists: ../stim/audio/nat_00609.wav
# File exists: ../stim/audio/nat_02102.wav
# File exists: ../stim/audio/nat_01475.wav
# File exists: ../stim/audio/nat_02116.wav
# File exists: ../stim/audio/nat_00994.wav
# File exists: ../stim/audio/nat_01590.wav
# File exists: ../stim/audio/nat_00929.wav
# File exists: ../stim/audio/nat_00358.wav
# File exists: ../stim/audio/nat_01630.wav
# File exists: ../stim/audio/nat_01341.wav
# File exists: ../stim/audio/nat_00520.wav
# File exists: ../stim/audio/nat_00757.wav
# File exists: ../stim/audio/nat_00551.wav
# File exists: ../stim/audio/nat_00493.wav
# File exists: ../stim/audio/nat_00277.wav
# File exists: ../stim/audio/nat_00041.wav
# File exists: ../stim/audio/nat_00236.wav
# File exists: ../stim/audio/nat_00058.wav
# File exists: ../stim/audio/nat_02033.wav
# File exists: ../stim/audio/nat_01558.wav
# File exists: ../stim/audio/nat_01550.wav
# File exists: ../stim/audio/nat_01756.wav
# File exists: ../stim/audio/nat_01138.wav
# File exists: ../stim/audio/nat_01968.wav
# File exists: ../stim/audio/nat_01763.wav
# File exists: ../stim/audio/nat_00363.wav
# File exists: ../stim/audio/nat_00208.wav
# File exists: ../stim/audio/nat_00592.wav
# File exists: ../stim/audio/nat_00720.wav
# File exists: ../stim/audio/nat_01179.wav
# File exists: ../stim/audio/nat_01739.wav
# File exists: ../stim/audio/nat_01192.wav
# File exists: ../stim/audio/nat_00631.wav
# File exists: ../stim/audio/nat_02053.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 5/17
# File exists: ../stim/audio/nat_01228.wav
# File exists: ../stim/audio/nat_01783.wav
# File exists: ../stim/audio/nat_01009.wav
# File exists: ../stim/audio/nat_00733.wav
# File exists: ../stim/audio/nat_01329.wav
# File exists: ../stim/audio/nat_01465.wav
# File exists: ../stim/audio/nat_00505.wav
# File exists: ../stim/audio/nat_01022.wav
# File exists: ../stim/audio/nat_00706.wav
# File exists: ../stim/audio/nat_01767.wav
# File exists: ../stim/audio/nat_01355.wav
# File exists: ../stim/audio/nat_00118.wav
# File exists: ../stim/audio/nat_01314.wav
# File exists: ../stim/audio/nat_01469.wav
# File exists: ../stim/audio/nat_00522.wav
# File exists: ../stim/audio/nat_00745.wav
# File exists: ../stim/audio/nat_00006.wav
# File exists: ../stim/audio/nat_00380.wav
# File exists: ../stim/audio/nat_00672.wav
# File exists: ../stim/audio/nat_00774.wav
# File exists: ../stim/audio/nat_01322.wav
# File exists: ../stim/audio/nat_00084.wav
# File exists: ../stim/audio/nat_01502.wav
# File exists: ../stim/audio/nat_01455.wav
# File exists: ../stim/audio/nat_00329.wav
# File exists: ../stim/audio/nat_01749.wav
# File exists: ../stim/audio/nat_01111.wav
# File exists: ../stim/audio/nat_01866.wav
# File exists: ../stim/audio/nat_01835.wav
# File exists: ../stim/audio/nat_00513.wav
# File exists: ../stim/audio/nat_01839.wav
# File exists: ../stim/audio/nat_01880.wav
# File exists: ../stim/audio/nat_00287.wav
# File exists: ../stim/audio/nat_00926.wav
# File exists: ../stim/audio/nat_01653.wav
# File exists: ../stim/audio/nat_00941.wav
# File exists: ../stim/audio/nat_01644.wav
# File exists: ../stim/audio/nat_00087.wav
# File exists: ../stim/audio/nat_00081.wav
# File exists: ../stim/audio/nat_00451.wav
# File exists: ../stim/audio/nat_00490.wav
# File exists: ../stim/audio/nat_01086.wav
# File exists: ../stim/audio/nat_01571.wav
# File exists: ../stim/audio/nat_00164.wav
# File exists: ../stim/audio/nat_00986.wav
# File exists: ../stim/audio/nat_00999.wav
# File exists: ../stim/audio/nat_00976.wav
# File exists: ../stim/audio/nat_02079.wav
# File exists: ../stim/audio/nat_01894.wav
# File exists: ../stim/audio/nat_01418.wav
# File exists: ../stim/audio/nat_01216.wav
# File exists: ../stim/audio/nat_01805.wav
# File exists: ../stim/audio/nat_01825.wav
# File exists: ../stim/audio/nat_02095.wav
# File exists: ../stim/audio/nat_02110.wav
# File exists: ../stim/audio/nat_02012.wav
# File exists: ../stim/audio/nat_01287.wav
# File exists: ../stim/audio/nat_01380.wav
# File exists: ../stim/audio/nat_00327.wav
# File exists: ../stim/audio/nat_01836.wav
# File exists: ../stim/audio/nat_00964.wav
# File exists: ../stim/audio/nat_00834.wav
# File exists: ../stim/audio/nat_01962.wav
# File exists: ../stim/audio/nat_01913.wav
# File exists: ../stim/audio/nat_01444.wav
# File exists: ../stim/audio/nat_00832.wav
# File exists: ../stim/audio/nat_00177.wav
# File exists: ../stim/audio/nat_00879.wav
# File exists: ../stim/audio/nat_00442.wav
# File exists: ../stim/audio/nat_00777.wav
# File exists: ../stim/audio/nat_02082.wav
# File exists: ../stim/audio/nat_01157.wav
# File exists: ../stim/audio/nat_02029.wav
# File exists: ../stim/audio/nat_00221.wav
# File exists: ../stim/audio/nat_02036.wav
# File exists: ../stim/audio/nat_00348.wav
# File exists: ../stim/audio/nat_00054.wav
# File exists: ../stim/audio/nat_00643.wav
# File exists: ../stim/audio/nat_01606.wav
# File exists: ../stim/audio/nat_01710.wav
# File exists: ../stim/audio/nat_01121.wav
# File exists: ../stim/audio/nat_02129.wav
# File exists: ../stim/audio/nat_00457.wav
# File exists: ../stim/audio/nat_00018.wav
# File exists: ../stim/audio/nat_01676.wav
# File exists: ../stim/audio/nat_01578.wav
# File exists: ../stim/audio/nat_01368.wav
# File exists: ../stim/audio/nat_02040.wav
# File exists: ../stim/audio/nat_01738.wav
# File exists: ../stim/audio/nat_00974.wav
# File exists: ../stim/audio/nat_01684.wav
# File exists: ../stim/audio/nat_00086.wav
# File exists: ../stim/audio/nat_00423.wav
# File exists: ../stim/audio/nat_01575.wav
# File exists: ../stim/audio/nat_00031.wav
# File exists: ../stim/audio/nat_01491.wav
# File exists: ../stim/audio/nat_00113.wav
# File exists: ../stim/audio/nat_00174.wav
# File exists: ../stim/audio/nat_00722.wav
# File exists: ../stim/audio/nat_01131.wav
# File exists: ../stim/audio/nat_00677.wav
# File exists: ../stim/audio/nat_00589.wav
# File exists: ../stim/audio/nat_01323.wav
# File exists: ../stim/audio/nat_00214.wav
# File exists: ../stim/audio/nat_01331.wav
# File exists: ../stim/audio/nat_00285.wav
# File exists: ../stim/audio/nat_00700.wav
# File exists: ../stim/audio/nat_01452.wav
# File exists: ../stim/audio/nat_00931.wav
# File exists: ../stim/audio/nat_00341.wav
# File exists: ../stim/audio/nat_00987.wav
# File exists: ../stim/audio/nat_00083.wav
# File exists: ../stim/audio/nat_01622.wav
# File exists: ../stim/audio/nat_00048.wav
# File exists: ../stim/audio/nat_00669.wav
# File exists: ../stim/audio/nat_01272.wav
# File exists: ../stim/audio/nat_01054.wav
# File exists: ../stim/audio/nat_00881.wav
# File exists: ../stim/audio/nat_00560.wav
# File exists: ../stim/audio/nat_01963.wav
# File exists: ../stim/audio/nat_01964.wav
# File exists: ../stim/audio/nat_00932.wav
# File exists: ../stim/audio/nat_01566.wav
# File exists: ../stim/audio/nat_00962.wav
# File exists: ../stim/audio/nat_02009.wav
# File exists: ../stim/audio/nat_01338.wav
# File exists: ../stim/audio/nat_01954.wav
# File exists: ../stim/audio/nat_01406.wav
# File exists: ../stim/audio/nat_00428.wav
# File exists: ../stim/audio/nat_00147.wav
# File exists: ../stim/audio/nat_00360.wav
# File exists: ../stim/audio/nat_00155.wav
# File exists: ../stim/audio/nat_00855.wav
# File exists: ../stim/audio/nat_00179.wav
# File exists: ../stim/audio/nat_01017.wav
# File exists: ../stim/audio/nat_01569.wav
# File exists: ../stim/audio/nat_01709.wav
# File exists: ../stim/audio/nat_01335.wav
# File exists: ../stim/audio/nat_01290.wav
# File exists: ../stim/audio/nat_02111.wav
# File exists: ../stim/audio/nat_00528.wav
# File exists: ../stim/audio/nat_00802.wav
# File exists: ../stim/audio/nat_00601.wav
# File exists: ../stim/audio/nat_01490.wav
# File exists: ../stim/audio/nat_01811.wav
# File exists: ../stim/audio/nat_00346.wav
# File exists: ../stim/audio/nat_00435.wav
# File exists: ../stim/audio/nat_00938.wav
# File exists: ../stim/audio/nat_01233.wav
# File exists: ../stim/audio/nat_01075.wav
# File exists: ../stim/audio/nat_02081.wav
# File exists: ../stim/audio/nat_00312.wav
# File exists: ../stim/audio/nat_00178.wav
# File exists: ../stim/audio/nat_00566.wav
# File exists: ../stim/audio/nat_01646.wav
# File exists: ../stim/audio/nat_00936.wav
# File exists: ../stim/audio/nat_00468.wav
# File exists: ../stim/audio/nat_00136.wav
# File exists: ../stim/audio/nat_00326.wav
# File exists: ../stim/audio/nat_00968.wav
# File exists: ../stim/audio/nat_01557.wav
# File exists: ../stim/audio/nat_00824.wav
# File exists: ../stim/audio/nat_00660.wav
# File exists: ../stim/audio/nat_00629.wav
# File exists: ../stim/audio/nat_00243.wav
# File exists: ../stim/audio/nat_00308.wav
# File exists: ../stim/audio/nat_00500.wav
# File exists: ../stim/audio/nat_01747.wav
# File exists: ../stim/audio/nat_00385.wav
# File exists: ../stim/audio/nat_01057.wav
# File exists: ../stim/audio/nat_01100.wav
# File exists: ../stim/audio/nat_00430.wav
# File exists: ../stim/audio/nat_01210.wav
# File exists: ../stim/audio/nat_01926.wav
# File exists: ../stim/audio/nat_01025.wav
# File exists: ../stim/audio/nat_01744.wav
# File exists: ../stim/audio/nat_01193.wav
# File exists: ../stim/audio/nat_01160.wav
# File exists: ../stim/audio/nat_00406.wav
# File exists: ../stim/audio/nat_00621.wav
# File exists: ../stim/audio/nat_01118.wav
# File exists: ../stim/audio/nat_00813.wav
# File exists: ../stim/audio/nat_01551.wav
# File exists: ../stim/audio/nat_00181.wav
# File exists: ../stim/audio/nat_00949.wav
# File exists: ../stim/audio/nat_00778.wav
# File exists: ../stim/audio/nat_01660.wav
# File exists: ../stim/audio/nat_00370.wav
# File exists: ../stim/audio/nat_01720.wav
# File exists: ../stim/audio/nat_01326.wav
# File exists: ../stim/audio/nat_01456.wav
# File exists: ../stim/audio/nat_01525.wav
# File exists: ../stim/audio/nat_01800.wav
# File exists: ../stim/audio/nat_00296.wav
# File exists: ../stim/audio/nat_00377.wav
# File exists: ../stim/audio/nat_00798.wav
# File exists: ../stim/audio/nat_01231.wav
# File exists: ../stim/audio/nat_00461.wav
# File exists: ../stim/audio/nat_01310.wav
# File exists: ../stim/audio/nat_00904.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 6/17
# File exists: ../stim/audio/nat_00839.wav
# File exists: ../stim/audio/nat_00126.wav
# File exists: ../stim/audio/nat_00887.wav
# File exists: ../stim/audio/nat_00105.wav
# File exists: ../stim/audio/nat_02048.wav
# File exists: ../stim/audio/nat_01007.wav
# File exists: ../stim/audio/nat_00682.wav
# File exists: ../stim/audio/nat_01673.wav
# File exists: ../stim/audio/nat_00355.wav
# File exists: ../stim/audio/nat_02103.wav
# File exists: ../stim/audio/nat_01711.wav
# File exists: ../stim/audio/nat_01164.wav
# File exists: ../stim/audio/nat_01797.wav
# File exists: ../stim/audio/nat_01967.wav
# File exists: ../stim/audio/nat_02088.wav
# File exists: ../stim/audio/nat_01375.wav
# File exists: ../stim/audio/nat_01605.wav
# File exists: ../stim/audio/nat_00140.wav
# File exists: ../stim/audio/nat_01610.wav
# File exists: ../stim/audio/nat_01451.wav
# File exists: ../stim/audio/nat_01185.wav
# File exists: ../stim/audio/nat_01494.wav
# File exists: ../stim/audio/nat_01793.wav
# File exists: ../stim/audio/nat_00209.wav
# File exists: ../stim/audio/nat_01992.wav
# File exists: ../stim/audio/nat_00711.wav
# File exists: ../stim/audio/nat_01870.wav
# File exists: ../stim/audio/nat_01078.wav
# File exists: ../stim/audio/nat_00984.wav
# File exists: ../stim/audio/nat_01055.wav
# File exists: ../stim/audio/nat_00010.wav
# File exists: ../stim/audio/nat_01753.wav
# File exists: ../stim/audio/nat_00129.wav
# File exists: ../stim/audio/nat_01492.wav
# File exists: ../stim/audio/nat_00626.wav
# File exists: ../stim/audio/nat_01548.wav
# File exists: ../stim/audio/nat_00843.wav
# File exists: ../stim/audio/nat_00323.wav
# File exists: ../stim/audio/nat_01245.wav
# File exists: ../stim/audio/nat_01457.wav
# File exists: ../stim/audio/nat_00516.wav
# File exists: ../stim/audio/nat_01255.wav
# File exists: ../stim/audio/nat_00215.wav
# File exists: ../stim/audio/nat_00754.wav
# File exists: ../stim/audio/nat_00195.wav
# File exists: ../stim/audio/nat_00014.wav
# File exists: ../stim/audio/nat_01742.wav
# File exists: ../stim/audio/nat_01538.wav
# File exists: ../stim/audio/nat_00549.wav
# File exists: ../stim/audio/nat_01319.wav
# File exists: ../stim/audio/nat_00156.wav
# File exists: ../stim/audio/nat_01489.wav
# File exists: ../stim/audio/nat_01501.wav
# File exists: ../stim/audio/nat_00950.wav
# File exists: ../stim/audio/nat_00288.wav
# File exists: ../stim/audio/nat_00922.wav
# File exists: ../stim/audio/nat_01182.wav
# File exists: ../stim/audio/nat_00390.wav
# File exists: ../stim/audio/nat_00864.wav
# File exists: ../stim/audio/nat_00477.wav
# File exists: ../stim/audio/nat_00597.wav
# File exists: ../stim/audio/nat_00419.wav
# File exists: ../stim/audio/nat_00553.wav
# File exists: ../stim/audio/nat_00578.wav
# File exists: ../stim/audio/nat_01828.wav
# File exists: ../stim/audio/nat_00820.wav
# File exists: ../stim/audio/nat_01178.wav
# File exists: ../stim/audio/nat_02104.wav
# File exists: ../stim/audio/nat_00799.wav
# File exists: ../stim/audio/nat_02032.wav
# File exists: ../stim/audio/nat_01173.wav
# File exists: ../stim/audio/nat_00664.wav
# File exists: ../stim/audio/nat_00295.wav
# File exists: ../stim/audio/nat_01677.wav
# File exists: ../stim/audio/nat_01691.wav
# File exists: ../stim/audio/nat_02037.wav
# File exists: ../stim/audio/nat_00142.wav
# File exists: ../stim/audio/nat_01718.wav
# File exists: ../stim/audio/nat_01132.wav
# File exists: ../stim/audio/nat_00088.wav
# File exists: ../stim/audio/nat_01671.wav
# File exists: ../stim/audio/nat_00615.wav
# File exists: ../stim/audio/nat_00269.wav
# File exists: ../stim/audio/nat_00131.wav
# File exists: ../stim/audio/nat_00917.wav
# File exists: ../stim/audio/nat_00375.wav
# File exists: ../stim/audio/nat_02098.wav
# File exists: ../stim/audio/nat_00421.wav
# File exists: ../stim/audio/nat_01639.wav
# File exists: ../stim/audio/nat_00724.wav
# File exists: ../stim/audio/nat_01960.wav
# File exists: ../stim/audio/nat_01320.wav
# File exists: ../stim/audio/nat_00012.wav
# File exists: ../stim/audio/nat_01587.wav
# File exists: ../stim/audio/nat_01006.wav
# File exists: ../stim/audio/nat_01519.wav
# File exists: ../stim/audio/nat_00258.wav
# File exists: ../stim/audio/nat_01576.wav
# File exists: ../stim/audio/nat_01472.wav
# File exists: ../stim/audio/nat_01717.wav
# File exists: ../stim/audio/nat_00328.wav
# File exists: ../stim/audio/nat_00776.wav
# File exists: ../stim/audio/nat_00910.wav
# File exists: ../stim/audio/nat_00260.wav
# File exists: ../stim/audio/nat_00333.wav
# File exists: ../stim/audio/nat_01293.wav
# File exists: ../stim/audio/nat_00401.wav
# File exists: ../stim/audio/nat_00171.wav
# File exists: ../stim/audio/nat_00897.wav
# File exists: ../stim/audio/nat_01702.wav
# File exists: ../stim/audio/nat_00138.wav
# File exists: ../stim/audio/nat_01956.wav
# File exists: ../stim/audio/nat_01352.wav
# File exists: ../stim/audio/nat_01930.wav
# File exists: ../stim/audio/nat_00224.wav
# File exists: ../stim/audio/nat_01697.wav
# File exists: ../stim/audio/nat_01732.wav
# File exists: ../stim/audio/nat_00901.wav
# File exists: ../stim/audio/nat_01765.wav
# File exists: ../stim/audio/nat_00319.wav
# File exists: ../stim/audio/nat_00844.wav
# File exists: ../stim/audio/nat_01911.wav
# File exists: ../stim/audio/nat_00723.wav
# File exists: ../stim/audio/nat_00531.wav
# File exists: ../stim/audio/nat_00846.wav
# File exists: ../stim/audio/nat_01908.wav
# File exists: ../stim/audio/nat_00946.wav
# File exists: ../stim/audio/nat_00193.wav
# File exists: ../stim/audio/nat_00503.wav
# File exists: ../stim/audio/nat_00467.wav
# File exists: ../stim/audio/nat_00714.wav
# File exists: ../stim/audio/nat_00003.wav
# File exists: ../stim/audio/nat_00558.wav
# File exists: ../stim/audio/nat_01989.wav
# File exists: ../stim/audio/nat_00139.wav
# File exists: ../stim/audio/nat_00005.wav
# File exists: ../stim/audio/nat_00573.wav
# File exists: ../stim/audio/nat_00325.wav
# File exists: ../stim/audio/nat_00228.wav
# File exists: ../stim/audio/nat_01063.wav
# File exists: ../stim/audio/nat_01890.wav
# File exists: ../stim/audio/nat_00242.wav
# File exists: ../stim/audio/nat_00842.wav
# File exists: ../stim/audio/nat_00898.wav
# File exists: ../stim/audio/nat_01563.wav
# File exists: ../stim/audio/nat_02099.wav
# File exists: ../stim/audio/nat_01281.wav
# File exists: ../stim/audio/nat_01629.wav
# File exists: ../stim/audio/nat_00661.wav
# File exists: ../stim/audio/nat_00424.wav
# File exists: ../stim/audio/nat_01785.wav
# File exists: ../stim/audio/nat_01973.wav
# File exists: ../stim/audio/nat_00542.wav
# File exists: ../stim/audio/nat_00547.wav
# File exists: ../stim/audio/nat_02006.wav
# File exists: ../stim/audio/nat_02112.wav
# File exists: ../stim/audio/nat_00622.wav
# ...
# File exists: ../stim/audio/ctrl_00837.wav
# File exists: ../stim/audio/ctrl_00820.wav
# File exists: ../stim/audio/ctrl_00816.wav
# File exists: ../stim/audio/ctrl_00844.wav
# File exists: ../stim/audio/ctrl_00841.wav
# File exists: ../stim/audio/ctrl_00842.wav
# File exists: ../stim/audio/ctrl_00843.wav
# File exists: ../stim/audio/ctrl_00830.wav
# File exists: ../stim/audio/ctrl_00825.wav
# File exists: ../stim/audio/ctrl_00826.wav
# File exists: ../stim/audio/ctrl_00798.wav
# File exists: ../stim/audio/ctrl_00845.wav
# File exists: ../stim/audio/ctrl_00832.wav
# File exists: ../stim/audio/ctrl_00831.wav
# File exists: ../stim/audio/ctrl_00848.wav
# File exists: ../stim/audio/ctrl_00846.wav
# File exists: ../stim/audio/ctrl_00838.wav
# File exists: ../stim/audio/ctrl_00835.wav
# File exists: ../stim/audio/ctrl_00849.wav
# File exists: ../stim/audio/ctrl_00833.wav
# File exists: ../stim/audio/ctrl_00850.wav
# File exists: ../stim/audio/ctrl_00836.wav
# File exists: ../stim/audio/ctrl_00834.wav
# File exists: ../stim/audio/ctrl_00855.wav
# File exists: ../stim/audio/ctrl_00851.wav
# File exists: ../stim/audio/ctrl_00862.wav
# File exists: ../stim/audio/ctrl_00856.wav
# File exists: ../stim/audio/ctrl_00859.wav
# File exists: ../stim/audio/ctrl_00863.wav
# File exists: ../stim/audio/ctrl_00854.wav
# File exists: ../stim/audio/ctrl_00858.wav
# File exists: ../stim/audio/ctrl_00852.wav
# File exists: ../stim/audio/ctrl_00864.wav
# File exists: ../stim/audio/ctrl_00865.wav
# File exists: ../stim/audio/ctrl_00853.wav
# File exists: ../stim/audio/ctrl_00840.wav
# File exists: ../stim/audio/ctrl_00870.wav
# File exists: ../stim/audio/ctrl_00877.wav
# File exists: ../stim/audio/ctrl_00839.wav
# File exists: ../stim/audio/ctrl_00860.wav
# File exists: ../stim/audio/ctrl_00866.wav
# File exists: ../stim/audio/ctrl_00873.wav
# File exists: ../stim/audio/ctrl_00872.wav
# File exists: ../stim/audio/ctrl_00881.wav
# File exists: ../stim/audio/ctrl_00847.wav
# File exists: ../stim/audio/ctrl_00857.wav
# File exists: ../stim/audio/ctrl_00869.wav
# File exists: ../stim/audio/ctrl_00867.wav
# File exists: ../stim/audio/ctrl_00884.wav
# File exists: ../stim/audio/ctrl_00871.wav
# File exists: ../stim/audio/ctrl_00874.wav
# File exists: ../stim/audio/ctrl_00879.wav
# File exists: ../stim/audio/ctrl_00883.wav
# File exists: ../stim/audio/ctrl_00878.wav
# File exists: ../stim/audio/ctrl_00875.wav
# File exists: ../stim/audio/ctrl_00861.wav
# File exists: ../stim/audio/ctrl_00876.wav
# File exists: ../stim/audio/ctrl_00895.wav
# File exists: ../stim/audio/ctrl_00887.wav
# File exists: ../stim/audio/ctrl_00898.wav
# File exists: ../stim/audio/ctrl_00886.wav
# File exists: ../stim/audio/ctrl_00897.wav
# File exists: ../stim/audio/ctrl_00880.wav
# File exists: ../stim/audio/ctrl_00892.wav
# File exists: ../stim/audio/ctrl_00868.wav
# File exists: ../stim/audio/ctrl_00896.wav
# File exists: ../stim/audio/ctrl_00823.wav
# File exists: ../stim/audio/ctrl_00907.wav
# File exists: ../stim/audio/ctrl_00889.wav
# File exists: ../stim/audio/ctrl_00882.wav
# File exists: ../stim/audio/ctrl_00894.wav
# File exists: ../stim/audio/ctrl_00885.wav
# File exists: ../stim/audio/ctrl_00906.wav
# File exists: ../stim/audio/ctrl_00893.wav
# File exists: ../stim/audio/ctrl_00891.wav
# File exists: ../stim/audio/ctrl_00910.wav
# File exists: ../stim/audio/ctrl_00911.wav
# File exists: ../stim/audio/ctrl_00903.wav
# File exists: ../stim/audio/ctrl_00888.wav
# File exists: ../stim/audio/ctrl_00900.wav
# File exists: ../stim/audio/ctrl_00899.wav
# File exists: ../stim/audio/ctrl_00917.wav
# File exists: ../stim/audio/ctrl_00904.wav
# File exists: ../stim/audio/ctrl_00919.wav
# File exists: ../stim/audio/ctrl_00901.wav
# File exists: ../stim/audio/ctrl_00908.wav
# File exists: ../stim/audio/ctrl_00905.wav
# File exists: ../stim/audio/ctrl_00912.wav
# File exists: ../stim/audio/ctrl_00890.wav
# File exists: ../stim/audio/ctrl_00915.wav
# File exists: ../stim/audio/ctrl_00902.wav
# File exists: ../stim/audio/ctrl_00916.wav
# File exists: ../stim/audio/ctrl_00918.wav
# File exists: ../stim/audio/ctrl_00909.wav
# File exists: ../stim/audio/ctrl_00913.wav
# File exists: ../stim/audio/ctrl_00914.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 16/17
# File exists: ../stim/audio/ctrl_00921.wav
# File exists: ../stim/audio/ctrl_00920.wav
# File exists: ../stim/audio/ctrl_00922.wav
# File exists: ../stim/audio/ctrl_00924.wav
# File exists: ../stim/audio/ctrl_00929.wav
# File exists: ../stim/audio/ctrl_00932.wav
# File exists: ../stim/audio/ctrl_00928.wav
# File exists: ../stim/audio/ctrl_00925.wav
# File exists: ../stim/audio/ctrl_00923.wav
# File exists: ../stim/audio/ctrl_00927.wav
# File exists: ../stim/audio/ctrl_00931.wav
# File exists: ../stim/audio/ctrl_00930.wav
# File exists: ../stim/audio/ctrl_00926.wav
# File exists: ../stim/audio/ctrl_00933.wav
# File exists: ../stim/audio/ctrl_00936.wav
# File exists: ../stim/audio/ctrl_00935.wav
# File exists: ../stim/audio/ctrl_00940.wav
# File exists: ../stim/audio/ctrl_00938.wav
# File exists: ../stim/audio/ctrl_00939.wav
# File exists: ../stim/audio/ctrl_00942.wav
# File exists: ../stim/audio/ctrl_00934.wav
# File exists: ../stim/audio/ctrl_00945.wav
# File exists: ../stim/audio/ctrl_00937.wav
# File exists: ../stim/audio/ctrl_00947.wav
# File exists: ../stim/audio/ctrl_00941.wav
# File exists: ../stim/audio/ctrl_00946.wav
# File exists: ../stim/audio/ctrl_00943.wav
# File exists: ../stim/audio/ctrl_00948.wav
# File exists: ../stim/audio/ctrl_00949.wav
# File exists: ../stim/audio/ctrl_00955.wav
# File exists: ../stim/audio/ctrl_00952.wav
# File exists: ../stim/audio/ctrl_00958.wav
# File exists: ../stim/audio/ctrl_00953.wav
# File exists: ../stim/audio/ctrl_00956.wav
# File exists: ../stim/audio/ctrl_00954.wav
# File exists: ../stim/audio/ctrl_00960.wav
# File exists: ../stim/audio/ctrl_00951.wav
# File exists: ../stim/audio/ctrl_00944.wav
# File exists: ../stim/audio/ctrl_00950.wav
# File exists: ../stim/audio/ctrl_00959.wav
# File exists: ../stim/audio/ctrl_00964.wav
# File exists: ../stim/audio/ctrl_00965.wav
# File exists: ../stim/audio/ctrl_00957.wav
# File exists: ../stim/audio/ctrl_00963.wav
# File exists: ../stim/audio/ctrl_00967.wav
# File exists: ../stim/audio/ctrl_00968.wav
# File exists: ../stim/audio/ctrl_00974.wav
# File exists: ../stim/audio/ctrl_00973.wav
# File exists: ../stim/audio/ctrl_00966.wav
# File exists: ../stim/audio/ctrl_00976.wav
# File exists: ../stim/audio/ctrl_00969.wav
# File exists: ../stim/audio/ctrl_00961.wav
# File exists: ../stim/audio/ctrl_00977.wav
# File exists: ../stim/audio/ctrl_00972.wav
# File exists: ../stim/audio/ctrl_00984.wav
# File exists: ../stim/audio/ctrl_00970.wav
# File exists: ../stim/audio/ctrl_00987.wav
# File exists: ../stim/audio/ctrl_00982.wav
# File exists: ../stim/audio/ctrl_00992.wav
# File exists: ../stim/audio/ctrl_00962.wav
# File exists: ../stim/audio/ctrl_00971.wav
# File exists: ../stim/audio/ctrl_00988.wav
# File exists: ../stim/audio/ctrl_00979.wav
# File exists: ../stim/audio/ctrl_00978.wav
# File exists: ../stim/audio/ctrl_00993.wav
# File exists: ../stim/audio/ctrl_00991.wav
# File exists: ../stim/audio/ctrl_00981.wav
# File exists: ../stim/audio/ctrl_00975.wav
# File exists: ../stim/audio/ctrl_00990.wav
# File exists: ../stim/audio/ctrl_00994.wav
# File exists: ../stim/audio/ctrl_00986.wav
# File exists: ../stim/audio/ctrl_00995.wav
# File exists: ../stim/audio/ctrl_00997.wav
# File exists: ../stim/audio/ctrl_00996.wav
# File exists: ../stim/audio/ctrl_00989.wav
# File exists: ../stim/audio/ctrl_01002.wav
# File exists: ../stim/audio/ctrl_00983.wav
# File exists: ../stim/audio/ctrl_00985.wav
# File exists: ../stim/audio/ctrl_01000.wav
# File exists: ../stim/audio/ctrl_00998.wav
# File exists: ../stim/audio/ctrl_01004.wav
# File exists: ../stim/audio/ctrl_00999.wav
# File exists: ../stim/audio/ctrl_01003.wav
# File exists: ../stim/audio/ctrl_01001.wav
# File exists: ../stim/audio/ctrl_01007.wav
# File exists: ../stim/audio/ctrl_01008.wav
# File exists: ../stim/audio/ctrl_01015.wav
# File exists: ../stim/audio/ctrl_01011.wav
# File exists: ../stim/audio/ctrl_01005.wav
# File exists: ../stim/audio/ctrl_01010.wav
# File exists: ../stim/audio/ctrl_01013.wav
# File exists: ../stim/audio/ctrl_01016.wav
# File exists: ../stim/audio/ctrl_01024.wav
# File exists: ../stim/audio/ctrl_01017.wav
# File exists: ../stim/audio/ctrl_01021.wav
# File exists: ../stim/audio/ctrl_01025.wav
# File exists: ../stim/audio/ctrl_01019.wav
# File exists: ../stim/audio/ctrl_01014.wav
# File exists: ../stim/audio/ctrl_01012.wav
# File exists: ../stim/audio/ctrl_01030.wav
# File exists: ../stim/audio/ctrl_01006.wav
# File exists: ../stim/audio/ctrl_01022.wav
# File exists: ../stim/audio/ctrl_01018.wav
# File exists: ../stim/audio/ctrl_01009.wav
# File exists: ../stim/audio/ctrl_01035.wav
# File exists: ../stim/audio/ctrl_01033.wav
# File exists: ../stim/audio/ctrl_01027.wav
# File exists: ../stim/audio/ctrl_01031.wav
# File exists: ../stim/audio/ctrl_01023.wav
# File exists: ../stim/audio/ctrl_01032.wav
# File exists: ../stim/audio/ctrl_01037.wav
# File exists: ../stim/audio/ctrl_01020.wav
# File exists: ../stim/audio/ctrl_01029.wav
# File exists: ../stim/audio/ctrl_01026.wav
# File exists: ../stim/audio/ctrl_01028.wav
# File exists: ../stim/audio/ctrl_01045.wav
# File exists: ../stim/audio/ctrl_01034.wav
# File exists: ../stim/audio/ctrl_00980.wav
# File exists: ../stim/audio/ctrl_01043.wav
# File exists: ../stim/audio/ctrl_01044.wav
# File exists: ../stim/audio/ctrl_01048.wav
# File exists: ../stim/audio/ctrl_01047.wav
# File exists: ../stim/audio/ctrl_01036.wav
# File exists: ../stim/audio/ctrl_01046.wav
# File exists: ../stim/audio/ctrl_01038.wav
# File exists: ../stim/audio/ctrl_01040.wav
# File exists: ../stim/audio/ctrl_01049.wav
# File exists: ../stim/audio/ctrl_01039.wav
# File exists: ../stim/audio/ctrl_01062.wav
# File exists: ../stim/audio/ctrl_01050.wav
# File exists: ../stim/audio/ctrl_01041.wav
# File exists: ../stim/audio/ctrl_01056.wav
# File exists: ../stim/audio/ctrl_01042.wav
# File exists: ../stim/audio/ctrl_01058.wav
# File exists: ../stim/audio/ctrl_01059.wav
# File exists: ../stim/audio/ctrl_01051.wav
# File exists: ../stim/audio/ctrl_01064.wav
# File exists: ../stim/audio/ctrl_01052.wav
# File exists: ../stim/audio/ctrl_01063.wav
# File exists: ../stim/audio/ctrl_01054.wav
# File exists: ../stim/audio/ctrl_01066.wav
# File exists: ../stim/audio/ctrl_01074.wav
# File exists: ../stim/audio/ctrl_01055.wav
# File exists: ../stim/audio/ctrl_01069.wav
# File exists: ../stim/audio/ctrl_01060.wav
# File exists: ../stim/audio/ctrl_01078.wav
# File exists: ../stim/audio/ctrl_01061.wav
# File exists: ../stim/audio/ctrl_01067.wav
# File exists: ../stim/audio/ctrl_01057.wav
# File exists: ../stim/audio/ctrl_01079.wav
# File exists: ../stim/audio/ctrl_01068.wav
# File exists: ../stim/audio/ctrl_01088.wav
# File exists: ../stim/audio/ctrl_01077.wav
# File exists: ../stim/audio/ctrl_01080.wav
# File exists: ../stim/audio/ctrl_01065.wav
# File exists: ../stim/audio/ctrl_01053.wav
# File exists: ../stim/audio/ctrl_01071.wav
# File exists: ../stim/audio/ctrl_01086.wav
# File exists: ../stim/audio/ctrl_01090.wav
# File exists: ../stim/audio/ctrl_01094.wav
# File exists: ../stim/audio/ctrl_01081.wav
# File exists: ../stim/audio/ctrl_01084.wav
# File exists: ../stim/audio/ctrl_01092.wav
# File exists: ../stim/audio/ctrl_01072.wav
# File exists: ../stim/audio/ctrl_01076.wav
# File exists: ../stim/audio/ctrl_01101.wav
# File exists: ../stim/audio/ctrl_01098.wav
# File exists: ../stim/audio/ctrl_01070.wav
# File exists: ../stim/audio/ctrl_01075.wav
# File exists: ../stim/audio/ctrl_01091.wav
# File exists: ../stim/audio/ctrl_01105.wav
# File exists: ../stim/audio/ctrl_01106.wav
# File exists: ../stim/audio/ctrl_01093.wav
# File exists: ../stim/audio/ctrl_01082.wav
# File exists: ../stim/audio/ctrl_01087.wav
# File exists: ../stim/audio/ctrl_01095.wav
# File exists: ../stim/audio/ctrl_01073.wav
# File exists: ../stim/audio/ctrl_01097.wav
# File exists: ../stim/audio/ctrl_01096.wav
# File exists: ../stim/audio/ctrl_01083.wav
# File exists: ../stim/audio/ctrl_01104.wav
# File exists: ../stim/audio/ctrl_01102.wav
# File exists: ../stim/audio/ctrl_01108.wav
# File exists: ../stim/audio/ctrl_01103.wav
# File exists: ../stim/audio/ctrl_01112.wav
# File exists: ../stim/audio/ctrl_01116.wav
# File exists: ../stim/audio/ctrl_01085.wav
# File exists: ../stim/audio/ctrl_01110.wav
# File exists: ../stim/audio/ctrl_01089.wav
# File exists: ../stim/audio/ctrl_01113.wav
# File exists: ../stim/audio/ctrl_01099.wav
# File exists: ../stim/audio/ctrl_01114.wav
# File exists: ../stim/audio/ctrl_01111.wav
# File exists: ../stim/audio/ctrl_01100.wav
# File exists: ../stim/audio/ctrl_01118.wav
# File exists: ../stim/audio/ctrl_01119.wav
# File exists: ../stim/audio/ctrl_01109.wav
# File exists: ../stim/audio/ctrl_01115.wav
# File exists: ../stim/audio/ctrl_01107.wav
# File exists: ../stim/audio/ctrl_01117.wav
# Waiting 0 seconds before next batch...
#
# Processing batch 17/17
# File exists: ../stim/audio/ctrl_01121.wav
# File exists: ../stim/audio/ctrl_01124.wav
# File exists: ../stim/audio/ctrl_01127.wav
# File exists: ../stim/audio/ctrl_01120.wav
# File exists: ../stim/audio/ctrl_01126.wav
# File exists: ../stim/audio/ctrl_01128.wav
# File exists: ../stim/audio/ctrl_01122.wav
# File exists: ../stim/audio/ctrl_01130.wav
# File exists: ../stim/audio/ctrl_01129.wav
# File exists: ../stim/audio/ctrl_01131.wav
# File exists: ../stim/audio/ctrl_01125.wav
# File exists: ../stim/audio/ctrl_01123.wav
# File exists: ../stim/audio/ctrl_01132.wav
# File exists: ../stim/audio/ctrl_01134.wav
# File exists: ../stim/audio/ctrl_01138.wav
# File exists: ../stim/audio/ctrl_01139.wav
# File exists: ../stim/audio/ctrl_01140.wav
# File exists: ../stim/audio/ctrl_01136.wav
# File exists: ../stim/audio/ctrl_01142.wav
# File exists: ../stim/audio/ctrl_01143.wav
# File exists: ../stim/audio/ctrl_01133.wav
# File exists: ../stim/audio/ctrl_01144.wav
# File exists: ../stim/audio/ctrl_01146.wav
# File exists: ../stim/audio/ctrl_01145.wav
# File exists: ../stim/audio/ctrl_01148.wav
# File exists: ../stim/audio/ctrl_01135.wav
# File exists: ../stim/audio/ctrl_01137.wav
# File exists: ../stim/audio/ctrl_01147.wav
# File exists: ../stim/audio/ctrl_01151.wav
# File exists: ../stim/audio/ctrl_01141.wav
# File exists: ../stim/audio/ctrl_01152.wav
# File exists: ../stim/audio/ctrl_01154.wav
# File exists: ../stim/audio/ctrl_01159.wav
# File exists: ../stim/audio/ctrl_01157.wav
# File exists: ../stim/audio/ctrl_01150.wav
# File exists: ../stim/audio/ctrl_01160.wav
# File exists: ../stim/audio/ctrl_01163.wav
# File exists: ../stim/audio/ctrl_01153.wav
# File exists: ../stim/audio/ctrl_01158.wav
# File exists: ../stim/audio/ctrl_01161.wav
# File exists: ../stim/audio/ctrl_01155.wav
# File exists: ../stim/audio/ctrl_01149.wav
# File exists: ../stim/audio/ctrl_01165.wav
# File exists: ../stim/audio/ctrl_01162.wav
# File exists: ../stim/audio/ctrl_01169.wav
# File exists: ../stim/audio/ctrl_01168.wav
# File exists: ../stim/audio/ctrl_01164.wav
# File exists: ../stim/audio/ctrl_01156.wav
# File exists: ../stim/audio/ctrl_01166.wav
# File exists: ../stim/audio/ctrl_01171.wav
# File exists: ../stim/audio/ctrl_01176.wav
# File exists: ../stim/audio/ctrl_01173.wav
# File exists: ../stim/audio/ctrl_01167.wav
# File exists: ../stim/audio/ctrl_01177.wav
# File exists: ../stim/audio/ctrl_01172.wav
# File exists: ../stim/audio/ctrl_01178.wav
# File exists: ../stim/audio/ctrl_01185.wav
# File exists: ../stim/audio/ctrl_01183.wav
# File exists: ../stim/audio/ctrl_01181.wav
# File exists: ../stim/audio/ctrl_01170.wav
# File exists: ../stim/audio/ctrl_01179.wav
# File exists: ../stim/audio/ctrl_01174.wav
# File exists: ../stim/audio/ctrl_01175.wav
# File exists: ../stim/audio/ctrl_01184.wav
# File exists: ../stim/audio/ctrl_01186.wav
# File exists: ../stim/audio/ctrl_01182.wav
# File exists: ../stim/audio/ctrl_01180.wav
# File exists: ../stim/audio/ctrl_01188.wav
# File exists: ../stim/audio/ctrl_01193.wav
# File exists: ../stim/audio/ctrl_01195.wav
# File exists: ../stim/audio/ctrl_01190.wav
# File exists: ../stim/audio/ctrl_01192.wav
# File exists: ../stim/audio/ctrl_01198.wav
# File exists: ../stim/audio/ctrl_01199.wav
# File exists: ../stim/audio/ctrl_01189.wav
# File exists: ../stim/audio/ctrl_01187.wav
# File exists: ../stim/audio/ctrl_01197.wav
# File exists: ../stim/audio/ctrl_01196.wav
# File exists: ../stim/audio/ctrl_01194.wav
# File exists: ../stim/audio/ctrl_01191.wav
#
# Generation complete:
# Successful generations: 3280
# Failed generations: 0

# %%
# Compute how many total characters there are in the dataset
total_characters = sum(final_df['sentence'].apply(len))
total_characters
