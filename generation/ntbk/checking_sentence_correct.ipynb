# %% [markdown]
# # Notebook to check if generated sentences are correct...

# %%
from pathlib import Path
import pandas as pd

filepath = Path('/home/co/data/MindSentences/download/sourcedata/sentences_dataset.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# ## Functions to check if sentences are correct

# %%
OPENAI_API_KEY = "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"
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)


def gpt4_response(prompt, model="gpt-4o-mini"):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model=model,
    )

    return chat_completion.choices[0].message.content


from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from tqdm import tqdm

def check_sentence_syntax(sentence):
    prompt = f"""Is this sentence syntatictly correct? 
Reply with exactly one word: 'correct': the sentence is correct in terms of syntax, 'incorrect': issues about syntax, or 'unsure' (other issues, but not linked to syntax).
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        if response in ['correct', 'incorrect', 'unsure']:
            return response
        return 'unsure'
    except Exception:
        return 'unsure'

def check_sentence_semantics(sentence):
    prompt = f"""Is this sentence semantically correct? 
Reply with exactly one word: 'correct': the sentence is correct in terms of semantics, 'incorrect': issues about semantics, or 'unsure' (other issues, but not linked to semantics).
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        if response in ['correct', 'incorrect', 'unsure']:
            return response
        return 'unsure'
    except Exception:
        return 'unsure'
    
def check_sentence_basic(sentence):
    prompt = f"""Is this sentence correct? 
Reply with exactly one word: 'correct': the sentence is perfectly fine, 'incorrect': there is something from with the sentence.
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        if response in ['correct', 'incorrect', 'unsure']:
            return response
        return 'unsure'
    except Exception:
        return 'unsure'
    
def check_sentence_huge_issue(sentence):
    prompt = f"""Is this sentence more or less correct? 
Reply with exactly one word: 'correct': the sentence seems fine, makes some sense even if it is a bit complex, 'incorrect': this sentence doesn't make any sense at all.
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        if response in ['correct', 'incorrect', 'unsure']:
            return response
        return 'unsure'
    except Exception:
        return 'unsure'

from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from tqdm import tqdm

def process_dataframe_parallel(df, max_workers=32, check=""):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Create futures for all sentences at once
        if check == "semantics":
            futures = {
                executor.submit(check_sentence_semantics, row['sentence']): idx 
                for idx, row in df.iterrows()
            }
        
        elif check == "syntax":
            futures = {
                executor.submit(check_sentence_syntax, row['sentence']): idx 
                for idx, row in df.iterrows()
            }
        elif check == "basic":
            futures = {
                executor.submit(check_sentence_basic, row['sentence']): idx 
                for idx, row in df.iterrows()
            }
        elif check == "huge_issue":
            futures = {
                executor.submit(check_sentence_huge_issue, row['sentence']): idx 
                for idx, row in df.iterrows()
            }
        else:
            raise ValueError("Invalid check")
        results = []
        for future in tqdm(futures, total=len(futures), desc="Processing sentences"):
            try:
                result = future.result()
                idx = futures[future]
                results.append((idx, result))
            except Exception as e:
                idx = futures[future]
                results.append((idx, 'unsure'))
    
    # Sort and add results to dataframe
    results.sort(key=lambda x: x[0])
    df[f'validity_{check}'] = [r[1] for r in results]
    
    return df

# %%
# Usage
df_controlled = df.query('dataset == "controlled"')
# df_syntax = process_dataframe_parallel(df_controlled, max_workers=32, check="syntax")

# %% [markdown]
# ## Test initial controlled dataset..

# %%
initial_controlled_dataset_path = Path('./../stim/sentences/relatives/relatives_ordered.csv')
initial_controlled_df = pd.read_csv(initial_controlled_dataset_path)

initial_controlled_df_huge_issues = process_dataframe_parallel(initial_controlled_df, max_workers=32, check="huge_issue")
# Out:
# Processing sentences: 100%|██████████| 1200/1200 [00:27<00:00, 44.25it/s]

# %%
initial_controlled_df_huge_issues.validity_huge_issue.value_counts()
# Out:
# validity_huge_issue
# correct      1090
# incorrect     109
# unsure          1
# Name: count, dtype: int64

# %%
# Save it 
initial_controlled_df_huge_issues.to_csv('/home/co/data/MindSentences/download/sourcedata/initial_controlled_huge_issues.csv', index=False)

# %%
for sen in initial_controlled_df_huge_issues.query('validity_huge_issue == "incorrect"').sentence:
    print(sen)
# Out:
# Customers that reviews praise buy the product.
# Customers that reviews praise eagerly buy the product.
# Happy customers that reviews praise buy the product.
# Happy customers that reviews praise eagerly buy the product.
# Teachers who discussed the plans that included some new activities greet students.
# Computers which were new solved the problem.
# The car that my friend likes that has leather seats stops.
# The car that my friend likes that has leather seats abruptly stops.
# The shiny car that my friend likes that has leather seats stops.
# The shiny car that my friend likes that has leather seats abruptly stops.
# The chefs who cooked the pasta that was delicious prepare dinner.
# The chefs who cooked the pasta that was delicious quickly prepare dinner.
# The experienced chefs who cooked the pasta that was delicious prepare dinner.
# The experienced chefs who cooked the pasta that was delicious quickly prepare dinner.
# Rains heavily poured.
# Heavy rains heavily poured.
# Heavy rains from the clouds heavily poured.
# Rains that gathered quickly heavily poured.
# Heavy rains that gathered quickly heavily poured.
# Rains which storms began poured.
# Rains which storms began heavily poured.
# Heavy rains which storms began poured.
# Heavy rains which storms began heavily poured.
# Rains that formed in the clouds which moved rapidly heavily poured.
# Heavy rains that formed in the clouds which moved rapidly poured.
# Heavy rains that formed in the clouds which moved rapidly heavily poured.
# The children that their friends joined felt joy.
# The children that their friends joined always felt joy.
# The happy children that their friends joined felt joy.
# The happy children that their friends joined always felt joy.
# Journalists who read the article that appeared online quickly report the news.
# The buyer who called the manager that was polite purchased the item.
# The eager buyer who called the manager that was polite purchased the item.
# The therapist who cares attentively listens.
# The empathetic therapist who cares attentively listens.
# The therapist who studied the case that was confidential listens.
# The empathetic therapist who studied the case that was confidential listens.
# The sofa that arrived yesterday which I ordered online needs repair.
# The sofa that arrived yesterday which I ordered online urgently needs repair.
# The old sofa that arrived yesterday which I ordered online needs repair.
# The old sofa that arrived yesterday which I ordered online urgently needs repair.
# Birds that migrate sang.
# Birds that migrate loudly sang.
# Wild birds that migrate sang.
# Wild birds that migrate loudly sang.
# Birds that flew over the river which flowed rapidly loudly sang.
# Wild birds that flew over the river which flowed rapidly loudly sang.
# Teachers who worked hard passionately taught students.
# Dedicated teachers who worked hard passionately taught students.
# Teachers that children respected passionately taught students.
# Dedicated teachers that children respected passionately taught students.
# Teachers who read the materials that were relevant passionately taught students.
# Dedicated teachers who read the materials that were relevant passionately taught students.
# Large buses which commuters used stopped.
# The customer who saw the offer that was online eagerly buys the shirt.
# Computers which students analyze quickly solve equations.
# Advanced computers which students analyze solve equations.
# Advanced computers which students analyze quickly solve equations.
# The bird which children watch loudly sings.
# The small bird which children watch loudly sings.
# The chilly wind that felt cold blew.
# The chilly wind that felt cold gently blew.
# The chilly wind which raised dust blew.
# The chilly wind which raised dust gently blew.
# Painters who arrived early fix the walls.
# Painters who arrived early quickly fix the walls.
# Skilled painters who arrived early quickly fix the walls.
# The diligent students who learned from the tutor that taught well finished the exam.
# The chef who trained hard quickly cooks a meal.
# The talented chef who trained hard quickly cooks a meal.
# Leaves that cover the ground that had dry soil fall gently.
# Leaves that cover the ground that had dry soil always fall gently.
# Colorful leaves that cover the ground that had dry soil fall gently.
# Colorful leaves that cover the ground that had dry soil always fall gently.
# Siblings who love sports played outside.
# Young siblings who love sports played outside.
# Siblings that you watched played outside.
# Young siblings that you watched played outside.
# Siblings frequently argue often.
# Older siblings frequently argue often.
# Siblings in the same room frequently argue often.
# Older siblings in the same room frequently argue often.
# Siblings who often disagree frequently argue often.
# Older siblings who disagree argue often.
# Older siblings who often disagree frequently argue often.
# Siblings that parents scold argue often.
# Older siblings that parents scold argue often.
# Older siblings that parents scold frequently argue often.
# Siblings who play games that involve strategies frequently argue often.
# Older siblings who play games that involve strategies frequently argue often.
# My sister that my friends admire visits the park.
# My sister that my friends admire often visits the park.
# My younger sister that my friends admire visits the park.
# My younger sister that my friends admire often visits the park.
# Students who learned the material that was challenging complete the assignment.
# Students who learned the material that was challenging quickly complete the assignment.
# Diligent students who learned the material that was challenging complete the assignment.
# Artists who painted the landscape that amazed everyone created the sculpture.
# Artists who painted the landscape that amazed everyone skillfully created the sculpture.
# Talented artists who painted the landscape that amazed everyone created the sculpture.
# Buses on the highway quickly drive fast.
# Modern buses on the highway quickly drive fast.
# Modern buses that run on time safely drive safely.
# Buses which people take drive efficiently.
# Modern buses which people take drive efficiently.
# Modern buses which people take efficiently drive efficiently.
# Modern buses that have routes which people prefer drive regularly.
# Modern buses that have routes which people prefer regularly drive regularly.
# The child who told a story that amused the passengers boarded the train.

# %% [markdown]
# ## Test controlled dataset semantic add

# %% [markdown]
# ### Big issue

# %%
df_controlled = df.query('dataset == "controlled"')
df_controlled_issue = process_dataframe_parallel(df_controlled, max_workers=32, check="huge_issue")
# Out:
# Processing sentences: 100%|██████████| 1200/1200 [00:37<00:00, 31.83it/s]
# /tmp/ipykernel_184095/2265936187.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'validity_{check}'] = [r[1] for r in results]

# %%
df_controlled_issue.validity_huge_issue.value_counts()
# Out:
# validity_huge_issue
# correct      985
# incorrect    213
# unsure         2
# Name: count, dtype: int64

# %% [markdown]
# ### Smaller issue

# %%
# Save
df_syntax.to_csv('/home/co/data/MindSentences/download/sourcedata/sentences_dataset_syntax.csv', index=False)

# %%
df_syntax.validity_syntax.value_counts()
# Out:
# validity_syntax
# correct      1015
# incorrect     185
# Name: count, dtype: int64

# %%
df_syntax_semantics = process_dataframe_parallel(df_syntax, max_workers=32, check="semantics")
# Out:
# Processing sentences: 100%|██████████| 1200/1200 [02:48<00:00,  7.11it/s]
# /tmp/ipykernel_184095/128754751.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'validity_{check}'] = [r[1] for r in results]

# %%
df_syntax_semantics.validity_semantics.value_counts()
# Out:
# validity_semantics
# correct      951
# incorrect    249
# Name: count, dtype: int64

# %%
df_syntax_semantics.to_csv('/home/co/data/MindSentences/download/sourcedata/sentences_dataset_syntax_semantics.csv', index=False)

# %%
for sent in df_syntax_semantics.query('validity_semantics == "incorrect"').sentence:
    print(sent)
# Out:
# Clients who frequent regularly buy the item.
# Buyers that reviews praise buy the good.
# Customers that reviews praise enthusiastically buy the product.
# Happy buyers that critiques praise acquire the item.
# Content customers that reviews praise eagerly buy the product.
# Physicians who study healthcare heal the signs.
# Capable physicians who research medicine promptly heal the signs.
# Physicians that clients rely address the manifestations.
# Skilled doctors that patients rely treat the symptoms.
# Competent doctors who read the reports that are pressing promptly treat the symptoms.
# The physicians immediately cared the patient.
# The skilled physicians cared the invalid.
# The physicians at the hospital promptly cared the sufferer.
# The medics who labored late cared the patient.
# The doctors who worked late instantly cared the patient.
# The skilled physicians who worked late immediately cared the patient.
# The doctors that everyone commended cared the patient.
# The physicians who researched the drug that was newly authorized immediately healed the invalid.
# Teachers who came promptly receive students.
# Friendly educators who arrived promptly greet students.
# Instructors who discussed the plans that included some new activities greet pupils.
# Professors who discussed the plans that included some new activities warmly welcome pupils.
# Friendly instructors who discussed the plans that included some new activities warmly welcome students.
# Faithful clients who kept money bought the item.
# Machines which were new fixed the problem.
# Machines that engineers constructed quickly answered the problem.
# Speedy computers that repaired the fault which was in the code answered the issue.
# The car at the intersection abruptly stops.
# The glossy car at the intersection pauses.
# The glossy car that I operate suddenly stops.
# The car that my friend enjoys that has leather seats stops.
# The car that my friend likes that has leather seats suddenly stops.
# The shiny car that my friend likes that has leather seats stops.
# The sparkly car that my friend likes that has leather seats suddenly stops.
# The chefs in the galley prepare meal.
# The experienced chefs in the kitchen promptly cook meal.
# The skilled cooks who cooked the pasta that was delicious prepare dinner.
# The experienced chefs who cooked the pasta that was tasty quickly make meal.
# Rains intensely poured.
# Heavy rains heavily poured.
# Rains from the clouds poured.
# Rains from the clouds heavily poured.
# Heavy downpours from the skies heavily gushed.
# Rains that amassed quickly heavily poured.
# Intense rains that gathered quickly heavily poured.
# Rains which storms began poured.
# Rains which storms began heavily poured.
# Intense showers which storms began poured.
# Heavy rains which tempests began heavily poured.
# Showers that formed in the clouds which moved quickly poured.
# Rains that formed in the clouds which shifted quickly heavily streamed.
# Heavy showers that formed in the skies which traveled rapidly poured.
# Heavy rains that formed in the clouds which shifted rapidly heavily poured.
# The children always felt delight.
# The content children who gamed well experienced happiness.
# The kids that their friends joined felt joy.
# The children that their friends joined always felt joy.
# The happy children that their friends joined felt joy.
# The joyful children that their friends joined always felt joy.
# The employees that everyone contracted mended the ceiling.
# Hardworking reporters who examine profoundly quickly relay the news.
# Diligent journalists that readers rely quickly announce the information.
# The purchaser who called the manager that was polite purchased the item.
# The buyer who called the manager that was courteous quickly bought the product.
# The enthusiastic buyer who called the manager that was polite purchased the item.
# The enthusiastic purchaser who called the manager that was polite quickly purchased the product.
# The therapist closely listens.
# The therapist who tends attentively hears.
# The empathetic therapist who concerns listens.
# The empathetic therapist who cares attentively listens.
# The counselor that customers rely hears.
# The therapist that clients rely attentively listens.
# The empathetic counselor that clients rely listens.
# The counselor who examined the case that was private hears.
# The counselor who examined the case that was private carefully hears.
# The empathetic counselor who reviewed the case that was confidential listens.
# The compassionate counselor who analyzed the situation that was confidential attentively listens.
# The couch needs fix.
# The old sofa requires fix.
# The couch in the living room needs fix.
# The old couch in the living room needs fix.
# The couch that I purchased immediately needs fix.
# The sofa which my friend recommended needs fix.
# The couch which my friend suggested urgently requires fix.
# The ancient couch which my friend endorsed urgently requires fix.
# The couch that arrived yesterday which I ordered online needs mending.
# The couch that arrived yesterday which I purchased online urgently needs repair.
# The ancient sofa that arrived recently which I ordered online needs repair.
# The old sofa that arrived yesterday which I ordered online urgently needs repair.
# Untamed fowl that migrate sang.
# Wild birds that migrate loudly chanted.
# Fowl that flew over the stream which flowed rapidly loudly chanted.
# Untamed birds that soared over the river which flowed rapidly loudly chanted.
# Dedicated instructors who worked hard fervently taught students.
# Committed instructors who read the resources that were relevant passionately educated learners.
# The competitor who prepares intensely triumphs the award.
# The competitor who trains intensely easily triumphs the trophy.
# The athletes ran the contest.
# The runners quickly sprinted the race.
# The resolute runners sprinted the race.
# The resolute athletes swiftly sprinted the race.
# Competitors from the city sprinted the event.
# Competitors from the town fast sprinted the race.
# Resolute sportspeople from the city swiftly sprinted the race.
# Competitors who trained hard quickly ran the contest.
# Resolute competitors who prepared hard sprinted the contest.
# Players that everyone admired promptly sprinted the race.
# Resolved athletes who understood the coach that led the squad swiftly sprinted the competition.
# Industrious pupils enthusiastically participated lectures.
# Students in the library joined lectures.
# Students in the library avidly visited talks.
# Diligent learners that professors recommended visited lectures.
# Industrious learners that professors endorsed keenly participated lectures.
# Diligent pupils who composed compositions that impressed the educator visited talks.
# Coaches that ran regularly ceased.
# The client who peruses daily purchases the shirt.
# The content customer who peruses daily buys the top.
# The client who saw the deal that was online purchases the shirt.
# The customer who saw the offer that was online eagerly buys the shirt.
# The pleased client who noticed the proposal that was online buys the shirt.
# The pleased customer who saw the offer that was online keenly buys the shirt.
# Sophisticated devices that professors use answer formulas.
# Computers which learners analyze solve equations.
# Advanced computers which learners analyze resolve equations.
# The avian on the branch chirps.
# The bird which kids observe loudly sings.
# The small bird which youth watch vociferously sings.
# The wind breezed.
# The chilly breeze that felt cold gusted.
# The chilly wind that felt cold gently wafted.
# The breeze which raised dust blew.
# The breeze which raised dust gently blew.
# The cold wind which raised dust gently blew.
# The breeze that came from the tempest which was far blew.
# The cool breeze that came from the storm which was far blew.
# Artists repair the barriers.
# Painters swiftly repair the partitions.
# Skilled painters in the house repair the walls.
# Painters who arrived early fix the walls.
# Painters who arrived early quickly fix the walls.
# Expert artists who arrived early fix the walls.
# Expert artists who arrived early swiftly fix the barriers.
# Painters who chose colors that fit the decor quickly repair the walls.
# Participants in the ground launch the ball.
# Expert athletes who practice in the court that coaches reserve shoot the ball.
# The starving children in the cookhouse ate the fruit.
# The kids who engaged outside swiftly ate the apple.
# The children that located the apple swiftly ate it.
# The educator who prepares carefully explains the lesson.
# The dedicated instructor who examines the content that is challenging explains the class.
# Artists execute the tune.
# Talented performers who practice habitually intensely perform the melody.
# Talented performers that listeners cherish intensely play the harmony.
# The learners who learned from the tutor that instructed well quickly finished the test.
# The diligent students who learned from the tutor that taught well finished the exam.
# The culinary makes a meal.
# The gifted cook who prepared hard cooks a meal.
# The nurse who completed swiftly gently inspects the wound.
# The alert nurse who completed rapidly checks the injury.
# The caretaker that clients rely gently inspects the wound.
# The alert nurse that patients trust checks the wound.
# The observant nurse that patients rely lightly examines the cut.
# The nurse who attended for the patient that was in pain examines the wound.
# Plants that grow quickly always give shade.
# Tall woods that animals climb provide shade.
# Vibrant foliage on the woods always fall softly.
# Vivid foliage that autumn brings always fall lightly.
# Leaves that blanket the earth that had dry soil fall gently.
# Leaves that cover the ground that had dry soil always fall gently.
# Vibrant foliage that cover the ground that had dry soil fall lightly.
# Vivid foliage that blanket the ground that had arid soil always fall softly.
# Sisters who love sports played outside.
# Siblings that you watched played outside.
# Siblings that you watched happily played outside.
# Young brothers that you watched played outside.
# Young siblings who met the friend that lives nearby happily amused outside.
# Siblings frequently quarrel often.
# Older brothers frequently dispute often.
# Siblings in the same room often argue often.
# Elder sisters in the same room frequently argue often.
# Siblings who disagree debate often.
# Siblings who often disagree often argue often.
# Older brothers who conflict quarrel often.
# Older sisters who often differ frequently argue often.
# Brothers that parents chide quarrel frequently.
# Sisters that parents scold regularly dispute regularly.
# Older siblings that guardians scold dispute often.
# Older siblings that parents scold frequently dispute often.
# Sisters who engage contests that entail tactics argue frequently.
# Siblings who play games that involve strategies frequently quarrel frequently.
# Older brothers who play games that involve strategies regularly argue often.
# The skilled developer that colleagues admire codes the code.
# My younger sister attends the park.
# My younger sister often attends the park.
# My younger sister with the book often attends the park.
# My younger sister who loves novels attends the park.
# My junior sister who loves books often visits the park.
# My sister that my friends admire visits the park.
# My sister that my buddies esteem often attends the garden.
# My younger sister that my friends admire attends the park.
# My younger sibling that my friends admire often frequents the park.
# My sister who found the book that was in the library often attends the park.
# My junior sister who found the volume that was in the library attends the park.
# The politician promptly joins the meeting.
# The influential lawmaker who reviews the talk that inspires confidence participates the gathering.
# A child in the space adores the tale.
# A child in the space really adores the tale.
# A child that listened it truly loves the story.
# The talented artist that audiences appreciate proficiently produces art.
# Learners that educators help finalize the homework.
# Hardworking learners that teachers help rapidly finish the assignment.
# Students who mastered the material that was challenging finish the assignment.
# Learners who learned the material that was demanding quickly finish the assignment.
# Diligent students who understood the material that was demanding finish the homework.
# The kid senses pleased.
# The happy child senses happy.
# The child in the park senses joyful.
# The kid who plays often truly experiences happy.
# The child that everyone reveres genuinely perceives happy.
# The cheerful child that everyone admires truly senses happy.
# The kid who sees the friend that is kind senses glad.
# Talented artists who enrolled school skillfully created the sculpture.
# Artists who painted the landscape that amazed everyone skillfully crafted the sculpture.
# Gifted artists who illustrated the landscape that astounded everyone created the sculpture.
# Gifted artists who painted the landscape that amazed everyone skillfully created the sculpture.
# The painter depicted a image.
# The gifted painter illustrated a drawing.
# The gifted painter rapidly crafted a image.
# The artist with the brush painted a image.
# The painter with the brush rapidly painted a image.
# The talented artist with the brush depicted a image.
# The artist who loved art painted a image.
# The gifted artist who loved painting quickly painted a image.
# The painter that critics adored crafted a image.
# The talented artist who saw the board that was in the studio depicted a image.
# The hot sun which rises soon constantly shines brightly.
# A industrious pupil who reads books writes a note.
# A pupil who found the book that was missing quickly writes a letter.
# A industrious student who found the book that was missing quickly composes a letter.
# Current coaches rapidly drive down the street.
# Buses on the highway quickly drive swiftly.
# Modern coaches on the highway quickly navigate fast.
# Modern buses that run on time safely drive safely.
# Coaches which passengers catch operate effectively.
# Buses which individuals take efficiently drive efficiently.
# Modern coaches which people take drive effectively.
# Modern buses which people take efficiently drive efficiently.
# Contemporary coaches that have paths which people like drive consistently.
# Contemporary coaches that have paths which people prefer regularly operate regularly.
# The child that everyone seen boarded the train.
# The child who told a story that entertained the passengers boarded the train.
# The eager child who told a story that amused the passengers boarded the train.

# %% [markdown]
# ## Test naturalistic dataset

# %% [markdown]
# ### Big issues

# %%
df_natural = df.query('dataset == "naturalistic"')
df_natural

# Process the semantics
df_natural_issues = process_dataframe_parallel(df_natural, max_workers=32, check="huge_issue")
# Out:
# Processing sentences: 100%|██████████| 2080/2080 [02:11<00:00, 15.77it/s]
# /tmp/ipykernel_201455/2265936187.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'validity_{check}'] = [r[1] for r in results]

# %%
df_natural_issues.validity_huge_issue.value_counts()
# Out:
# validity_huge_issue
# correct      1930
# incorrect     150
# Name: count, dtype: int64

# %%
df_natural_issues.validity_huge_issue.value_counts()
# Out:
# validity_huge_issue
# correct      1926
# incorrect     153
# unsure          1
# Name: count, dtype: int64

# %% [markdown]
# ### Smaller problems

# %%
df_natural = df.query('dataset == "naturalistic"')
df_natural

# Process the semantics
df_natural_semantics = process_dataframe_parallel(df_natural, max_workers=32, check="basic")
df_syntax_semantics
df_syntax_semantics.to_csv('/home/co/data/MindSentences/download/sourcedata/sentences_natural_basic.csv', index=False)
# Out:
# Processing sentences: 100%|██████████| 2080/2080 [01:50<00:00, 18.87it/s]
# /tmp/ipykernel_184095/2881824156.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'validity_{check}'] = [r[1] for r in results]

# %%
df_natural_semantics.validity_basic.value_counts()
# Out:
# validity_basic
# correct      1755
# incorrect     324
# unsure          1
# Name: count, dtype: int64

# %%
for sentence in df_natural_semantics.query('validity_semantics == "incorrect"').sentence:
    print(sentence)
# Out:
# Had the stars not been visible at night?
# She will board the ferry by the river early morning
# Bring the flowers for your friend after you felt happy
# Paint these walls once they finished dinner
# Their floors with the carpet aren't easy to clean
# They must not board the ferry but they have to travel
# Avoid paintings since artists will not paint tomorrow
# Birds will sing at dawn when the sun will rise
# Tell her friend to bring dessert for the party next time
# Make sure you don't skip the train
# Don't fish under the bridge across the lake back then
# Have a regular schedule for better sleep soon
# Please don't leave but close the window when you go
# Will the leaves fall when autumn will be here?
# Aren't children eating vegetables while parents aren't cooking them?
# Stop practicing your song since you played it before already
# Had tourists visited that museum last year?
# Are those buses not running a night service during the summer?
# Make sure you won't use sugar in your tea from now on
# Could you run without pain along the track yesterday?
# Her children that read daily improve quickly
# Don't learn about history in the museum today
# The train ride didn't cause fear in the evening
# Your friends hadn't visited last night
# Prepare the vegetables before the guests arrived
# Had the students not completed their assignments on time?
# The library isn't open yet people wait outside
# The birds hadn't left since it did not become cold
# Gather your notes before the meeting that just ended
# She will not join the gym so she will not get fit
# Please don't plant those flowers before the frost had come
# Please don't keep that painting if it was sold already
# Don't try exercises you weren't trained for yesterday
# Please do not clean the kitchen while I fixed the sink
# Are the friends who visit often at your house today?
# The windows hadn't been cleaned last week
# Never believe his siblings enjoyed visiting our home
# Do not paint today while you do not have time
# Study the results from those experiments thoroughly yesterday
# Aren't your colleagues not meeting for lunch anymore?
# Do not start your sketch since the art class ended early today
# Did the shoes fit better after they bought them?
# Try not to avoid the thoughts that will bring you peace
# Stop cooking those vegetables for they did not taste fresh
# Do not go to the market while they will not be open
# The items weren't available nor were they coming soon
# Do not use this software unless you were trained already
# Don't start eating yet while others haven't arrived
# Don't try to reach her because she hadn't been available
# A winter breeze isn't cold in the desert
# Do the children across the street not play outside today?
# You shouldn't visit them before the dinner last night
# Did your friends never exercise to stay healthy before now?
# Ensure he didn't use the computer which was broken yesterday
# You mustn't ignore the feedback they had given during the exhibit
# Tell your siblings they played together at the park
# Aren't those drinks that you mentioned not available tomorrow?
# Don't walk along the road when it won't be safe
# You should not buy tickets now if prices will increase next week
# Don’t wear shoes in the house during their visit yesterday
# You didn't wait for happiness by the phone yesterday
# Isn't the app you use daily not working now?
# Do your siblings not play outside in the garden today?
# Ensure that students who finish early will help others
# The stores were busy because many people had sales to attend
# Aren't the parents who cook well not making dinner today?
# Please remember you shouldn't board the ferry that has left
# Never think their kids enjoyed the long trip
# Never play music so loudly if people cannot appreciate it
# Do not clean the windows which you hadn't cleaned yesterday
# You should not assume where she is not going today
# Don't skip your breakfast time
# The window is not open for fresh air
# Don't sketch without your tools later
# Is their flight on time today?
# Do not ignore your siblings where you need their help
# Does your sister on the phone plan to visit us soon?
# Hadn't the device on my desk needed any repairs last week?
# Please don't believe their prices won’t increase later
# Had she trained at the gym last week?
# Ask for help if she will find it difficult
# Is their offer still available today?
# The bread won't have baked correctly tomorrow
# Do not paint in the dark tomorrow
# Had the match started while did you arrive late to it?
# I hadn't bought any new furniture last month
# Shall the bakery in town reduce their bread prices next morning?
# The guests won't stay longer than they plan
# She cannot play with you nor does she want to try
# Don't choose items over those broken shelves
# Aren't the stars which shine at night not easily visible today?
# Do not run behind the track today
# Aren't those books on the shelf not on discount today?
# Had those items not sold out quickly last month?
# The tourists will explore around the city next week
# Bring snacks nor should you forget to bring drinks
# Do not paint the wall for it was not dry
# Tell stories to guests after they finished their meal
# Let happiness bloom inside the room often
# Please don't buy tickets without discounts at the museum last Friday
# Is winter coming but the snow has not arrived yet?
# You mustn't play music where it wasn't allowed
# Don't you all eat sugar tomorrow
# His mood had not improved yesterday evening
# Do not wait for trains which never arrived on time before
# Don't eat the cake yet it's not ready
# Aren't these stories not making people sad today?
# The child will call her mother when school will be over
# You will not ride a bus yet could still be late
# Are your parents visiting us if their train leaves on time?
# You must not leave while the lecture does not finish
# He should not leave his shoes outside before it will rain later
# Don’t choose a taxi while it does not seem safe
# My cousins visiting today aren't coming by train
# Ask if he wasn't at the meeting yesterday
# Do not miss the train that just left
# They will not shop online if the store offers deals
# Visit the town where your friend had stayed
# Do not drop the equipment for safety is important here
# Never move the chair yet you must clean under it
# Their families who visit us often will enjoy the dinner
# Never skip training unless all the players who are fit stopped
# Don't visit the museum unless tickets were available
# The neighbors shared tools for everyone had repairs to make
# Do not repair the chairs that are broken yet
# She will not find a taxi if there isn't any rain
# You won't feel better unless healthy habits get its practice daily
# Do storms form fast for the clouds gather quickly today?
# Will those shelves which we need not be installed then?
# Do not purchase if discounts were missing yesterday
# You will not need any bags during the purchase inside there
# Prepare the snacks after you will choose your favorite movie
# Weren't the services they offered last year not available anymore?
# A cold will not improve fast so you must take care
# Aren't the people who always help us not available anymore?
# You must not believe the stories your grandparents never shared with you
# This room will not need paint nor will the hallway
# The student will not attend the lecture nor will he study
# Take the buses before they were full of passengers
# You shouldn't choose the job that wasn't offered
# They will need to check online for some prices will drop tonight
# Had the parents not seen their friends last week?
# Wasn't the ocean that you visited not calm yesterday?
# Don't neglect that a healthy diet had not fixed all issues yet
# The bakery won't have bread when you will go late in the afternoon
# Does a student not feel prepared when he will study enough?
# Do not purchase items that will not go on sale
# Won't your parents by the garden be eating dinner later?
# Do not be going outside during the storm
# The rain does not stop today
# Don't store the clothes yet the winter had not finished
# Do not wait for happiness for problems weren't going away
# Please don't tell the brother that he will not know
# Avoid using the notes if you hadn't learned them
# Do your shoes under the bed not fit you anymore?
# Isn't the wind not going to be too strong later?
# Isn't the coffee that you like not available today?
# You should never fix the chair that was already broken
# The child will not finish lunch behind the house
# Had the fridge in the corner not been cold enough?
# Don't assume everything had a sale yesterday
# You must not leave the path which was never used
# You shouldn't buy extra furniture for they had no space left
# The flowers did not bloom when winter had ended
# Please do not swim in the river because it was not clean
# Is the river between the hills not clear next week?
# People must not skip breakfast yet they often do it
# The stars in the clear sky weren't visible last night
# You shouldn't skip dinner while you will be out playing
# The guide will not explain during the journey tomorrow
# The device will not start while it will stay off
# He will take the bus when the train will be full
# Ask about their day when they will come back home
# You mustn't drive when fog doesn't clear up
# The stores weren't open for the sales ended early
# Let me know when you finished your training yesterday
# My heart won't feel light while the music will play loudly

# %% [markdown]
# # Trying to fix sentences using a LLM, and checking the result in terms of validity

# %%
df_natural_issues
# Out:
#         tense       dataset         theme  num_words    structure  \
# 0      future  naturalistic       emotion          7       simple
# 1      future  naturalistic  relationship         11  preposition
# 2     present  naturalistic          food          5       simple
# 3     present  naturalistic      humanity          9  preposition
# 4        past  naturalistic        health          7  independent
# ...       ...           ...           ...        ...          ...
# 2075   future  naturalistic        health          5       simple
# 2076     past  naturalistic          food         11  preposition
# 2077     past  naturalistic          work          7       simple
# 2078  present  naturalistic          work          8    dependent
# 2079   future  naturalistic      shopping          7       simple
#
#      audio_filename sentence_id numerosity  \
# 0     nat_00282.wav   nat_00282     plural
# 1     nat_02008.wav   nat_02008   singular
# 2     nat_01713.wav   nat_01713   singular
# 3     nat_01666.wav   nat_01666   singular
# 4     nat_02066.wav   nat_02066   singular
# ...             ...         ...        ...
# 2075  nat_01016.wav   nat_01016   singular
# 2076  nat_01275.wav   nat_01275   singular
# 2077  nat_00455.wav   nat_00455   singular
# 2078  nat_00815.wav   nat_00815   singular
# 2079  nat_00995.wav   nat_00995   singular
#
#                                                sentence validity_huge_issue
# 0                       The kids will find joy in games             correct
# 1     Will your cousin not be at the museum with us ...             correct
# 2                             The bread isn't baked yet             correct
# 3      Study the painting with a guide from the gallery             correct
# 4            I wasn't aware there was therapy available             correct
# ...                                                 ...                 ...
# 2075                    Your mood won't affect everyone             correct
# 2076  He wasn't eating any snacks from the office ta...             correct
# 2077            He prepared the lecture notes last week             correct
# 2078            The test which you prepared for is easy             correct
# 2079           That service will not improve next month             correct
#
# [2080 rows x 10 columns]

# %%
# Let's do it first for the naturalistic dataset
incorrect_sentences_natural =  df_natural_issues.query('validity_huge_issue == "incorrect"').loc[:300]

def correct_sentence_with_gpt4(sentence: str) -> str:
    """Get GPT-4 correction for a sentence."""
    prompt = f"""
    Correct the following sentence:
    {sentence}
    and output only the corrected sentence.

    Follow the following constraints:
    - build a sentence that is both syntactically and semantically correct
    - do not add or remove words: use synonyms but keep the same part of speech
    - keep the same meaning, tense, plurality etc..
    """
    return gpt4_response(prompt)

def correct_sentence_with_liberty(sentence: str) -> str:
    """Get GPT-4 correction for a sentence."""
    prompt = f"""
    The following sentence is incorrect:
    {sentence}
    build a SIMPLE AND SYNTACTICALLY AND SEMANTICALLY CORRECT sentence with the same theme and basic vocabulary, and output only the new sentence.
    """
    return gpt4_response(prompt, model="gpt-4o")

# incorrect_sentences_natural_fixed = pd.DataFrame(incorrect_sentences_natural['sentence'].apply(correct_sentence_with_gpt4))

incorrect_sentences_natural_fixed_liberty = pd.DataFrame(incorrect_sentences_natural['sentence'].apply(correct_sentence_with_liberty))

# %%
# Now run it through the huge issue check
corrected_sentences_natural_liberty = process_dataframe_parallel(incorrect_sentences_natural_fixed_liberty, max_workers=32, check="huge_issue")
# Out:
# Processing sentences:   0%|          | 0/19 [00:00<?, ?it/s]
# Processing sentences: 100%|██████████| 19/19 [00:00<00:00, 19.71it/s]

# %%
not_corrected_sentences_natural = process_dataframe_parallel(incorrect_sentences_natural, max_workers=32, check="huge_issue")
not_corrected_sentences_natural.validity_huge_issue.value_counts()
# Out:
# Processing sentences: 100%|██████████| 19/19 [00:04<00:00,  4.16it/s]
# validity_huge_issue
# incorrect    17
# correct       2
# Name: count, dtype: int64

# %%
corrected_sentences_natural_liberty.validity_huge_issue.value_counts()

# Compare the number of words between the original and the corrected sentences, sentence to sentence. 
# Very naively:
# Out:
# validity_huge_issue
# correct      18
# incorrect     1
# Name: count, dtype: int64

# %%
for sen in corrected_sentences_natural_liberty.query('validity_huge_issue == "incorrect"').sentence:
    print(sen)
# Out:
# Stop practicing your song because you have already played it.

# %%
for sent_corr, sent_init in zip(corrected_sentences_natural_liberty.query('validity_huge_issue == "incorrect"').sentence, incorrect_sentences_natural.query('validity_huge_issue == "incorrect"').sentence):
    print(sent_corr)
    print(sent_init)
# Out:
# Had the flowers not bloomed in the spring?
# Had the stars not been visible at night?
# Avoid sculptures because sculptors will not carve today.
# Bring the flowers for your friend after you felt happy
# Don't swim in the river behind the park last summer.
# Paint these walls once they finished dinner
# Please don't forget but turn off the lights before you leave.
# Their floors with the carpet aren't easy to clean
# Stop rehearsing your piece since you performed it already.
# Will I find peace if everything will change tomorrow?
# The storm will arrive soon as it will disrupt the calm.
# They must not board the ferry but they have to travel
# Are those buses not operating a night service throughout the summer?
# Avoid paintings since artists will not paint tomorrow

# %%
for sentence in df_syntax_semantics.query('validity_syntax == "incorrect"').sentence[:10]:
    prompt_to_correct = f"""
    Correct the following sentence:
    {sentence}
    and output only the corrected sentence.

    Follow the following constraints:
    - build a sentence that is both syntactically and semantically correct
    - do not add or remove words: use synonyms but keep the same part of speech: we want the exact same amount of words
    - keep the same meaning, tense, plurality etc..
    """
    print("Before correction: ", sentence)
    print("After correction: ", gpt4_response(prompt_to_correct))
    print("                                      ")
# Out:
# Before correction:  Clients who frequent regularly buy the item.
# After correction:  Clients who visit regularly purchase the item.
#
# Before correction:  Buyers that reviews praise buy the good.
# After correction:  Buyers whose reviews commend buy the product.
#
# Before correction:  Customers that reviews praise enthusiastically buy the product.
# After correction:  Customers whose reviews praise enthusiastically buy the product.
#
# Before correction:  Happy buyers that critiques praise acquire the item.
# After correction:  Joyful purchasers that reviews applaud obtain the item.
#
# Before correction:  Content customers that reviews praise eagerly buy the product.
# After correction:  Satisfied customers whose reviews extol eagerly purchase the product.
#
# Before correction:  Physicians that clients rely address the manifestations.
# After correction:  Physicians whom clients depend on handle the manifestations.
#
# Before correction:  Skilled doctors that patients rely treat the symptoms.
# After correction:  Skilled doctors whom patients depend on address the symptoms.
#
# Before correction:  The physicians immediately cared the patient.
# After correction:  The physicians immediately attended to the patient.
#
# Before correction:  The skilled physicians cared the invalid.
# After correction:  The skilled physicians attended to the invalid.
#
# Before correction:  The physicians at the hospital promptly cared the sufferer.
# After correction:  The physicians at the hospital promptly tended the sufferer.

# %%
# Usage
df = df.query('dataset == "controlled"')
processed_df = process_dataframe_parallel(df)

# %%
processed_df.validity.value_counts()

# %%
processed_df.to_csv('/home/co/tmp/nina/sentences_dataset_validity.csv', index=False)

# %%
processed_df[processed_df.validity == 'incorrect']

# %% [markdown]
# ## Check processed sentences

# %%
import pandas as pd
processed_path = '/home/co/tmp/nina/sentences_dataset_validity.csv'
df = pd.read_csv(processed_path)

df
# Out:
#         tense     dataset      theme  num_words          structure  \
# 0     present  controlled   shopping          4           baseline
# 1     present  controlled   shopping          5         baseline_a
# 2     present  controlled   shopping          5         baseline_b
# 3     present  controlled   shopping          6         baseline_c
# 4     present  controlled   shopping          7            control
# ...       ...         ...        ...        ...                ...
# 1195     past  controlled  transport         10  standard_object_c
# 1196     past  controlled  transport         13             nested
# 1197     past  controlled  transport         14           nested_a
# 1198     past  controlled  transport         14           nested_b
# 1199     past  controlled  transport         15           nested_c
#
#       audio_filename sentence_id numerosity  \
# 0     ctrl_00000.wav  ctrl_00000     plural
# 1     ctrl_00001.wav  ctrl_00001     plural
# 2     ctrl_00002.wav  ctrl_00002     plural
# 3     ctrl_00003.wav  ctrl_00003     plural
# 4     ctrl_00004.wav  ctrl_00004     plural
# ...              ...         ...        ...
# 1195  ctrl_01195.wav  ctrl_01195   singular
# 1196  ctrl_01196.wav  ctrl_01196   singular
# 1197  ctrl_01197.wav  ctrl_01197   singular
# 1198  ctrl_01198.wav  ctrl_01198   singular
# 1199  ctrl_01199.wav  ctrl_01199   singular
#
#                                                sentence validity
# 0                                 Buyers buy the goods.  correct
# 1                       Customers eagerly buy the item.  correct
# 2                  Pleased customers acquire the goods.  correct
# 3     Pleased clients enthusiastically buy the product.  correct
# 4                Buyers on the website buy the product.  correct
# ...                                                 ...      ...
# 1195  The enthusiastic child that everyone observed ...  correct
# 1196  The child who told a story that entertained th...  correct
# 1197  The child who narrated a story that entertaine...  correct
# 1198  The eager child who told a story that amused t...  correct
# 1199  The eager child who told a story that amused t...  correct
#
# [1200 rows x 10 columns]

# %%
for row in df.query('validity == "incorrect"').itertuples():
    print(row.sentence_id, row.sentence)
# Out:
# ctrl_00008 Clients who frequent regularly buy the item.
# ctrl_00012 Buyers that reviews praise buy the good.
# ctrl_00013 Customers that reviews praise enthusiastically buy the product.
# ctrl_00014 Happy buyers that critiques praise acquire the item.
# ctrl_00015 Content customers that reviews praise eagerly buy the product.
# ctrl_00028 Physicians who study healthcare heal the signs.
# ctrl_00031 Capable physicians who research medicine promptly heal the signs.
# ctrl_00032 Physicians that clients rely address the manifestations.
# ctrl_00034 Skilled doctors that patients rely treat the symptoms.
# ctrl_00039 Competent doctors who read the reports that are pressing promptly treat the symptoms.
# ctrl_00041 The physicians immediately cared the patient.
# ctrl_00042 The skilled physicians cared the invalid.
# ctrl_00045 The physicians at the hospital promptly cared the sufferer.
# ctrl_00048 The medics who labored late cared the patient.
# ctrl_00049 The doctors who worked late instantly cared the patient.
# ctrl_00051 The skilled physicians who worked late immediately cared the patient.
# ctrl_00052 The doctors that everyone commended cared the patient.
# ctrl_00057 The physicians who researched the drug that was newly authorized immediately healed the invalid.
# ctrl_00068 Teachers who came promptly receive students.
# ctrl_00077 Professors who discussed the plans that included some new activities warmly welcome pupils.
# ctrl_00090 Faithful clients who kept money bought the item.
# ctrl_00108 Machines which were new fixed the problem.
# ctrl_00109 Computers which were new quickly resolved the problem.
# ctrl_00118 Speedy computers that repaired the fault which was in the code answered the issue.
# ctrl_00126 The glossy car at the intersection pauses.
# ctrl_00136 The car that my friend enjoys that has leather seats stops.
# ctrl_00137 The car that my friend likes that has leather seats suddenly stops.
# ctrl_00138 The shiny car that my friend likes that has leather seats stops.
# ctrl_00139 The sparkly car that my friend likes that has leather seats suddenly stops.
# ctrl_00144 The chefs in the galley prepare meal.
# ctrl_00147 The experienced chefs in the kitchen promptly cook meal.
# ctrl_00156 The cooks who prepared the pasta that was delicious prepare dinner.
# ctrl_00157 The chefs who cooked the pasta that was delicious swiftly prepare dinner.
# ctrl_00158 The skilled cooks who cooked the pasta that was delicious prepare dinner.
# ctrl_00159 The experienced chefs who cooked the pasta that was tasty quickly make meal.
# ctrl_00181 Rains intensely poured.
# ctrl_00183 Heavy rains heavily poured.
# ctrl_00185 Rains from the clouds heavily poured.
# ctrl_00191 Intense rains that gathered quickly heavily poured.
# ctrl_00192 Rains which storms began poured.
# ctrl_00193 Rains which storms began heavily poured.
# ctrl_00194 Intense showers which storms began poured.
# ctrl_00195 Heavy rains which tempests began heavily poured.
# ctrl_00197 Rains that formed in the clouds which shifted quickly heavily streamed.
# ctrl_00198 Heavy showers that formed in the skies which traveled rapidly poured.
# ctrl_00199 Heavy rains that formed in the clouds which shifted rapidly heavily poured.
# ctrl_00201 The children always felt delight.
# ctrl_00210 The content children who gamed well experienced happiness.
# ctrl_00212 The kids that their friends joined felt joy.
# ctrl_00213 The children that their friends joined always felt joy.
# ctrl_00214 The happy children that their friends joined felt joy.
# ctrl_00215 The joyful children that their friends joined always felt joy.
# ctrl_00252 The employees that everyone contracted mended the ceiling.
# ctrl_00271 Hardworking reporters who examine profoundly quickly relay the news.
# ctrl_00275 Diligent journalists that readers rely quickly announce the information.
# ctrl_00296 The purchaser who called the manager that was polite purchased the item.
# ctrl_00297 The buyer who called the manager that was courteous quickly bought the product.
# ctrl_00298 The enthusiastic buyer who called the manager that was polite purchased the item.
# ctrl_00299 The enthusiastic purchaser who called the manager that was polite quickly purchased the product.
# ctrl_00309 The therapist who tends attentively hears.
# ctrl_00310 The empathetic therapist who concerns listens.
# ctrl_00311 The empathetic therapist who cares attentively listens.
# ctrl_00312 The counselor that customers rely hears.
# ctrl_00313 The therapist that clients rely attentively listens.
# ctrl_00314 The empathetic counselor that clients rely listens.
# ctrl_00316 The counselor who examined the case that was private hears.
# ctrl_00317 The counselor who examined the case that was private carefully hears.
# ctrl_00318 The empathetic counselor who reviewed the case that was confidential listens.
# ctrl_00319 The compassionate counselor who analyzed the situation that was confidential attentively listens.
# ctrl_00320 The couch needs fix.
# ctrl_00322 The old sofa requires fix.
# ctrl_00324 The couch in the living room needs fix.
# ctrl_00326 The old couch in the living room needs fix.
# ctrl_00329 The couch that I purchased immediately needs fix.
# ctrl_00332 The sofa which my friend recommended needs fix.
# ctrl_00333 The couch which my friend suggested urgently requires fix.
# ctrl_00335 The ancient couch which my friend endorsed urgently requires fix.
# ctrl_00336 The couch that arrived yesterday which I ordered online needs mending.
# ctrl_00337 The couch that arrived yesterday which I purchased online urgently needs repair.
# ctrl_00338 The ancient sofa that arrived recently which I ordered online needs repair.
# ctrl_00339 The old sofa that arrived yesterday which I ordered online urgently needs repair.
# ctrl_00348 Fowl that migrate crooned.
# ctrl_00350 Untamed fowl that migrate sang.
# ctrl_00351 Wild birds that migrate loudly chanted.
# ctrl_00357 Fowl that flew over the stream which flowed rapidly loudly chanted.
# ctrl_00359 Untamed birds that soared over the river which flowed rapidly loudly chanted.
# ctrl_00371 Dedicated instructors who worked hard fervently taught students.
# ctrl_00379 Committed instructors who read the resources that were relevant passionately educated learners.
# ctrl_00388 The competitor who prepares intensely triumphs the award.
# ctrl_00389 The competitor who trains intensely easily triumphs the trophy.
# ctrl_00400 The athletes ran the contest.
# ctrl_00401 The runners quickly sprinted the race.
# ctrl_00402 The resolute runners sprinted the race.
# ctrl_00403 The resolute athletes swiftly sprinted the race.
# ctrl_00404 Competitors from the city sprinted the event.
# ctrl_00405 Competitors from the town fast sprinted the race.
# ctrl_00407 Resolute sportspeople from the city swiftly sprinted the race.
# ctrl_00409 Competitors who trained hard quickly ran the contest.
# ctrl_00410 Resolute competitors who prepared hard sprinted the contest.
# ctrl_00413 Players that everyone admired promptly sprinted the race.
# ctrl_00416 Players who knew the coach that guided the group sprinted the race.
# ctrl_00419 Resolved athletes who understood the coach that led the squad swiftly sprinted the competition.
# ctrl_00423 Industrious pupils enthusiastically participated lectures.
# ctrl_00425 Students in the library avidly visited talks.
# ctrl_00434 Diligent learners that professors recommended visited lectures.
# ctrl_00435 Industrious learners that professors endorsed keenly participated lectures.
# ctrl_00438 Diligent pupils who composed compositions that impressed the educator visited talks.
# ctrl_00490 The content customer who peruses daily buys the top.
# ctrl_00496 The client who saw the deal that was online purchases the shirt.
# ctrl_00497 The customer who saw the offer that was online eagerly buys the shirt.
# ctrl_00499 The pleased customer who saw the offer that was online keenly buys the shirt.
# ctrl_00510 Sophisticated devices that professors use answer formulas.
# ctrl_00512 Computers which learners analyze solve equations.
# ctrl_00514 Advanced computers which learners analyze resolve equations.
# ctrl_00524 The avian on the branch chirps.
# ctrl_00533 The bird which kids observe loudly sings.
# ctrl_00535 The small bird which youth watch vociferously sings.
# ctrl_00540 The wind breezed.
# ctrl_00550 The chilly breeze that felt cold gusted.
# ctrl_00551 The chilly wind that felt cold gently wafted.
# ctrl_00552 The breeze which raised dust blew.
# ctrl_00553 The breeze which raised dust gently blew.
# ctrl_00555 The cold wind which raised dust gently blew.
# ctrl_00556 The breeze that came from the tempest which was far blew.
# ctrl_00558 The cool breeze that came from the storm which was far blew.
# ctrl_00566 Skilled painters in the house repair the walls.
# ctrl_00569 Painters who arrived early quickly fix the walls.
# ctrl_00571 Expert artists who arrived early swiftly fix the barriers.
# ctrl_00584 Participants in the ground launch the ball.
# ctrl_00596 Athletes who practice in the court that coaches reserve shoot the ball.
# ctrl_00598 Expert athletes who practice in the court that coaches reserve shoot the ball.
# ctrl_00601 The children quickly ate the apple.
# ctrl_00609 The kids who engaged outside swiftly ate the apple.
# ctrl_00613 The children that located the apple swiftly ate it.
# ctrl_00638 The dedicated instructor who examines the content that is challenging explains the class.
# ctrl_00640 Artists execute the tune.
# ctrl_00651 Talented performers who practice habitually intensely perform the melody.
# ctrl_00676 The learners who learned from the instructor that taught well completed the exam.
# ctrl_00677 The learners who learned from the tutor that instructed well quickly finished the test.
# ctrl_00678 The diligent students who learned from the tutor that taught well finished the exam.
# ctrl_00740 The culinary makes a meal.
# ctrl_00750 The gifted cook who prepared hard cooks a meal.
# ctrl_00769 The nurse who completed swiftly gently inspects the wound.
# ctrl_00770 The alert nurse who completed rapidly checks the injury.
# ctrl_00775 The observant nurse that patients rely lightly examines the cut.
# ctrl_00807 Vibrant foliage on the woods always fall softly.
# ctrl_00815 Vivid foliage that autumn brings always fall lightly.
# ctrl_00816 Leaves that blanket the earth that had dry soil fall gently.
# ctrl_00817 Leaves that cover the ground that had dry soil always fall gently.
# ctrl_00818 Vibrant foliage that cover the ground that had dry soil fall lightly.
# ctrl_00819 Vivid foliage that blanket the ground that had arid soil always fall softly.
# ctrl_00832 Siblings that you watched played outside.
# ctrl_00839 Young siblings who met the friend that lives nearby happily amused outside.
# ctrl_00861 Siblings frequently quarrel often.
# ctrl_00863 Older brothers frequently dispute often.
# ctrl_00865 Siblings in the same room often argue often.
# ctrl_00867 Elder sisters in the same room frequently argue often.
# ctrl_00868 Siblings who disagree debate often.
# ctrl_00869 Siblings who often disagree often argue often.
# ctrl_00870 Older brothers who conflict quarrel often.
# ctrl_00871 Older sisters who often differ frequently argue often.
# ctrl_00872 Brothers that parents chide quarrel frequently.
# ctrl_00873 Sisters that parents scold regularly dispute regularly.
# ctrl_00874 Older siblings that guardians scold dispute often.
# ctrl_00875 Older siblings that parents scold frequently dispute often.
# ctrl_00876 Sisters who engage contests that entail tactics argue frequently.
# ctrl_00877 Siblings who play games that involve strategies frequently quarrel frequently.
# ctrl_00879 Older brothers who play games that involve strategies regularly argue often.
# ctrl_00890 The talented programmer who loves puzzles codes the code.
# ctrl_00894 The skilled developer that colleagues admire codes the code.
# ctrl_00902 My younger sister attends the park.
# ctrl_00903 My younger sister often attends the park.
# ctrl_00907 My younger sister with the book often attends the park.
# ctrl_00910 My younger sister who loves novels attends the park.
# ctrl_00912 My sister that my friends admire visits the park.
# ctrl_00913 My sister that my buddies esteem often attends the garden.
# ctrl_00914 My younger sister that my friends admire attends the park.
# ctrl_00915 My younger sibling that my friends admire often frequents the park.
# ctrl_00917 My sister who found the book that was in the library often attends the park.
# ctrl_00918 My junior sister who found the volume that was in the library attends the park.
# ctrl_00938 The influential lawmaker who reviews the talk that inspires confidence participates the gathering.
# ctrl_00945 A child in the space really adores the tale.
# ctrl_00953 A child that listened it truly loves the story.
# ctrl_00995 The talented artist that audiences appreciate proficiently produces art.
# ctrl_01009 Learners who examine often quickly finish the assignment.
# ctrl_01012 Learners that educators help finalize the homework.
# ctrl_01015 Hardworking learners that teachers help rapidly finish the assignment.
# ctrl_01016 Students who mastered the material that was challenging finish the assignment.
# ctrl_01017 Learners who learned the material that was demanding quickly finish the assignment.
# ctrl_01018 Diligent students who understood the material that was demanding finish the homework.
# ctrl_01040 The kid senses pleased.
# ctrl_01042 The happy child senses happy.
# ctrl_01044 The child in the park senses joyful.
# ctrl_01049 The kid who plays often truly experiences happy.
# ctrl_01053 The child that everyone reveres genuinely perceives happy.
# ctrl_01055 The cheerful child that everyone admires truly senses happy.
# ctrl_01056 The kid who sees the friend that is kind senses glad.
# ctrl_01071 Talented artists who enrolled school skillfully created the sculpture.
# ctrl_01077 Artists who painted the landscape that amazed everyone skillfully crafted the sculpture.
# ctrl_01078 Gifted artists who illustrated the landscape that astounded everyone created the sculpture.
# ctrl_01079 Gifted artists who painted the landscape that amazed everyone skillfully created the sculpture.
# ctrl_01100 The painter depicted a image.
# ctrl_01102 The gifted painter illustrated a drawing.
# ctrl_01103 The gifted painter rapidly crafted a image.
# ctrl_01104 The artist with the brush painted a image.
# ctrl_01105 The painter with the brush rapidly painted a image.
# ctrl_01106 The talented artist with the brush depicted a image.
# ctrl_01108 The artist who loved art painted a image.
# ctrl_01111 The gifted artist who loved painting quickly painted a image.
# ctrl_01112 The painter that critics adored crafted a image.
# ctrl_01118 The talented artist who saw the board that was in the studio depicted a image.
# ctrl_01131 The hot sun which rises soon constantly shines brightly.
# ctrl_01135 The warm sun that provides warmth always shines brightly.
# ctrl_01150 A industrious pupil who reads books writes a note.
# ctrl_01157 A pupil who found the book that was missing quickly writes a letter.
# ctrl_01159 A industrious student who found the book that was missing quickly composes a letter.
# ctrl_01165 Buses on the highway quickly drive swiftly.
# ctrl_01167 Modern coaches on the highway quickly navigate fast.
# ctrl_01169 Coaches that run on time safely drive safely.
# ctrl_01172 Coaches which passengers catch operate effectively.
# ctrl_01173 Buses which individuals take efficiently drive efficiently.
# ctrl_01174 Modern coaches which people take drive effectively.
# ctrl_01175 Modern buses which people take efficiently drive efficiently.
# ctrl_01179 Contemporary coaches that have paths which people prefer regularly operate regularly.
# ctrl_01192 The child that everyone seen boarded the train.

# %% [markdown]
# # Final Fix

# %% [markdown]
# ## Natural dataset

# %%
from concurrent.futures import ThreadPoolExecutor
import pandas as pd
from tqdm import tqdm

def process_dataframe_parallel(df, max_workers=32, check=""):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Create futures for all sentences at once
        if check == "huge_issue":
            futures = {
                executor.submit(check_sentence_huge_issue, row['sentence']): idx 
                for idx, row in df.iterrows()
            }
        else:
            raise ValueError("Invalid check")
        results = []
        for future in tqdm(futures, total=len(futures), desc="Processing sentences"):
            try:
                result = future.result()
                idx = futures[future]
                results.append((idx, result))
            except Exception as e:
                idx = futures[future]
                results.append((idx, 'unsure'))
    
    # Sort and add results to dataframe
    results.sort(key=lambda x: x[0])
    df[f'validity_{check}'] = [r[1] for r in results]
    
    return df


def check_sentence_huge_issue(sentence):
    prompt = f"""Is this sentence more or less correct? 
Reply with exactly one word: 'correct': the sentence seems fine, makes some sense even if it is a bit complex, 'incorrect': this sentence doesn't make any sense at all.
Sentence: "{sentence}"
"""
    try:
        response = gpt4_response(prompt).strip().lower()
        if response in ['correct', 'incorrect', 'unsure']:
            return response
        return 'unsure'
    except Exception as e:
        print(e)

        return 'unsure'
    

OPENAI_API_KEY = "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"
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)


def gpt4_response(prompt, model="gpt-4o-mini"):
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model=model,
    )

    return chat_completion.choices[0].message.content


from pathlib import Path
import pandas as pd

filepath = Path('/home/co/data/MindSentences/download/sourcedata/sentences_dataset.csv')
df = pd.read_csv(filepath)

df_natural = df.query('dataset == "naturalistic"')

df_natural_issues = process_dataframe_parallel(df_natural, max_workers=32, check="huge_issue")

def correct_sentence_with_liberty(sentence: str) -> str:
    """Get GPT-4 correction for a sentence."""
    prompt = f"""
    The following sentence is incorrect:
    {sentence}
    build a SIMPLE AND SYNTACTICALLY AND SEMANTICALLY CORRECT sentence with the same theme and basic vocabulary, and output only the new sentence.
    """
    return gpt4_response(prompt, model="gpt-4o")


# Apply corrections only to rows where validity_huge_issue == "incorrect"
df_natural_issues.loc[df_natural_issues['validity_huge_issue'] == "incorrect", 'sentence'] = \
    df_natural_issues.loc[df_natural_issues['validity_huge_issue'] == "incorrect", 'sentence'].apply(correct_sentence_with_liberty)

# Now df_natural_issues contains all sentences, with the incorrect ones fixed

# %%
print("Before correction: ", df_natural_issues.query('validity_huge_issue == "incorrect"').sentence)
print(df_natural_issues.validity_huge_issue.value_counts())

# Check if the corrections are correct
df_natural_issues = process_dataframe_parallel(df_natural_issues, max_workers=32, check="huge_issue")
print("After correction: ", df_natural_issues.query('validity_huge_issue == "incorrect"').sentence)
print(df_natural_issues.validity_huge_issue.value_counts())
# Out:
# Before correction:  5                    Were the stars not visible at night?
# 6       She will board the ferry by the river in the e...
# 10      Bring the flowers to your friend when you feel...
# 19      Did the kids in my group learn anything during...
# 22             Paint these walls once they finish dinner.
#                               ...
# 1974              The device will stay off and not start.
# 1978         He will take the bus when the train is full.
# 2011    The stores weren't open because the sales ende...
# 2019         Let me know when you finished your training.
# 2042    My heart won't feel light while the music play...
# Name: sentence, Length: 152, dtype: object
# validity_huge_issue
# correct      1928
# incorrect     152
# Name: count, dtype: int64
# Processing sentences: 100%|██████████| 2080/2080 [00:58<00:00, 35.82it/s]
# After correction:  88      Avoid paintings since artists are not painting...
# 225     The cold front will move through for it will c...
# 436     Are the friends who often visit at your house ...
# 533      Did the shoes fit better after they bought them?
# 551      Do not go to the market while they are not open.
# 661     Ensure he didn't use the computer which was br...
# 691     You should not buy tickets now if prices will ...
# 782          Do not run fast or you will not win the race
# 822           The window is not open to let in fresh air.
# 850                          The sun will not shine later
# 871            Ask for help if she will find it difficult
# 937     Did the match start while you arrived late to it?
# 1302             Don't miss painting the sunset right now
# 1414    Do not purchase if there were no discounts yes...
# 1471    The student will not attend the lecture nor wi...
# 1887    You shouldn't buy extra furniture because they...
# 2004          You mustn't drive when fog doesn't clear up
# 2019         Let me know when you finished your training.
# Name: sentence, dtype: object
# validity_huge_issue
# correct      2061
# incorrect      18
# unsure          1
# Name: count, dtype: int64
# /tmp/ipykernel_202759/3540393917.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'validity_{check}'] = [r[1] for r in results]

# %%
# Save the corrected dataset
df_natural_issues.to_csv('/home/co/data/MindSentences/download/sourcedata/sentences_natural_issues_fixed.csv', index=False)

# %%
# Now that I crrected it by hand, recheck!
df_natural_fixed_byhand = pd.read_csv('/home/co/data/MindSentences/download/sourcedata/sentences_natural_issues_fixed.csv')

df_natural_fixed_byhand = process_dataframe_parallel(df_natural_fixed_byhand, max_workers=32, check="huge_issue")

df_natural_fixed_byhand.validity_huge_issue.value_counts()
# Out:
# Processing sentences: 100%|██████████| 2080/2080 [01:33<00:00, 22.32it/s]
# validity_huge_issue
# correct      2062
# incorrect      18
# Name: count, dtype: int64

# %%
for sentence in df_natural_fixed_byhand.query('validity_huge_issue == "incorrect"').sentence:
    print(sentence)
# Out:
# Avoid galleries since artists are not painting tomorrow.
# Please don't keep that painting if it was sold already
# Are the friends who visit often at your house today?
# You didn't need to study it if the test was not tomorrow
# Ensure he doesn’t use the computer because it was broken yesterday
# The team will not compete for they lack the players
# Do not buy anything unless it is necessary now
# You mustn't play music where it wasn't allowed
# Do not miss the train that just left
#     Do storms form quickly when the clouds gather fast today?
# Do not buy if there were no discounts yesterday.
# The student will not attend the lecture nor will he study
# Gather the leaves if they will fall and the path will clear
# Birds will not sing at night nor will they fly
# Please don't tell the brother that he will not know
# You shouldn't buy extra furniture because they have no space left.
# You mustn't drive when fog doesn't clear up
# My brother will ride the bike to the school event

# %%
df_natural_fixed_byhand.to_csv('/home/co/data/MindSentences/download/sourcedata/sentences_natural_issues_fixed.csv', index=False)
